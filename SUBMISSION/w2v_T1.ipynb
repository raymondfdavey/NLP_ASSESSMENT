# %% [markdown]
# # CODE FOR ENTIRE W2V MODEL BUILDING AND TESTING FOR TASK 1

# %%
# imports

import os
import pandas as pd 
from gensim.models import KeyedVectors
import matplotlib.pyplot as plt
import nltk
from nltk import word_tokenize as tokenize
from nltk.corpus import stopwords as stopwords
from nltk.stem import PorterStemmer, SnowballStemmer
import torch
from torch.utils.data import DataLoader, Dataset
import numpy as np
from torch import nn
from tqdm import tqdm
import uuid
import re
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import json

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/rfd/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/rfd/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/rfd/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# loading data if in colab/not in colab

try :
  from google.colab import drive
  IN_COLAB = True
except:
  IN_COLAB = False
print('IN COLAB: ', IN_COLAB)


parentdir = "./propaganda_dataset_v2"
train_file= "propaganda_train.tsv"
val_file= "propaganda_val.tsv"

train_path=os.path.join(parentdir,train_file)
val_path=os.path.join(parentdir,val_file)

if IN_COLAB:
  train_path = '/content/propaganda_train.tsv'
  val_path = '/content/propaganda_val.tsv'

train_df=pd.read_csv(train_path,delimiter="\t",quotechar='|')
val_df=pd.read_csv(val_path,delimiter="\t",quotechar='|')
# Out:
# IN COLAB:  False

# %%
# pre-process data for binary task 
# remove snippet tags
# create binary target variable

def transform_binaryify(row):
    new_value = 0 if row['label'] == 'not_propaganda' else 1
    return new_value

def transform_strip_tag(row):
    sent = row['tagged_in_context']
    cleaned_string = sent.replace("<BOS>", "")
    cleaned_string = cleaned_string.replace("<EOS>", "")
    return cleaned_string


train_df['propaganda'] = train_df.apply(transform_binaryify, axis=1)
train_df['original_without_snip_tags'] = train_df.apply(transform_strip_tag, axis=1)


val_df['propaganda'] = val_df.apply(transform_binaryify, axis=1)
val_df['original_without_snip_tags'] = val_df.apply(transform_strip_tag, axis=1)

# check it has worked correctly

train_df
val_df
# Out:
#                          label  \
# 0               not_propaganda
# 1    causal_oversimplification
# 2     appeal_to_fear_prejudice
# 3               not_propaganda
# 4                   repetition
# ..                         ...
# 635             not_propaganda
# 636             not_propaganda
# 637             not_propaganda
# 638                flag_waving
# 639  causal_oversimplification
#
#                                      tagged_in_context  propaganda  \
# 0    On average, between 300 and 600 infections are...           0
# 1    Mostly because <BOS> the country would not las...           1
# 2    Lyndon Johnson <BOS> gets Earl Warren and Sen....           1
# 3             <BOS> You <EOS> may opt out at anytime.            0
# 4    It must be exacted from him directly in order ...           1
# ..                                                 ...         ...
# 635  NewsCatholic Church, <BOS> Family, Marriage <E...           0
# 636  Remember our saying, modern day fairy <BOS> ta...           0
# 637  Why <BOS> not <EOS> open up to Iran with massi...           0
# 638  <BOS> He also sang an Islamic State fight song...           1
# 639  We hear again, as we did incessantly from the ...           1
#
#                             original_without_snip_tags
# 0    On average, between 300 and 600 infections are...
# 1    Mostly because  the country would not last lon...
# 2    Lyndon Johnson  gets Earl Warren and Sen. Rich...
# 3                        You  may opt out at anytime.
# 4    It must be exacted from him directly in order ...
# ..                                                 ...
# 635           NewsCatholic Church,  Family, Marriage
# 636  Remember our saying, modern day fairy  tales s...
# 637  Why  not  open up to Iran with massive amounts...
# 638   He also sang an Islamic State fight song and ...
# 639  We hear again, as we did incessantly from the ...
#
# [640 rows x 4 columns]

# %%
# load in W2V vectors
pretrained_model_path = './GoogleNews-vectors-negative300.bin.gz' 
my_model = KeyedVectors.load_word2vec_format(pretrained_model_path, binary=True)

# %%
# further pre-processing
# these functions carry out the pre processing describe in the assignment
# they are called as part of the custom Dataset initialisation
# both functions take in a single string and return the word2vec pooled vector representation

def transform_tokens_to_w2v_with_stems(string, model, pool_type='mean', normalise = False):
    print('string:', string)
    
    stops = set(stopwords.words('english'))
    porter_stemmer = PorterStemmer()
    snowball_stemmer = SnowballStemmer('english')
    vectors = []
    original_tokens = tokenize(string)
    print('original tokens:', original_tokens)
    cleaned_tokens = [w for w in original_tokens if len(w) > 1 and w.isalpha() and w not in stops]
    print('cleaned:',cleaned_tokens)
    
    for token in cleaned_tokens:
        if token in model.key_to_index:
            vectors.append(model.get_vector(token, norm=normalise))
        else:
            print('STEMMING')
            porter_stem = porter_stemmer.stem(token)
            snowball_stem = snowball_stemmer.stem(token)

            if porter_stem in model.key_to_index:
                print('porter', porter_stem)
                vectors.append(model.get_vector(porter_stem, norm=normalise))
            elif snowball_stem in model.key_to_index:
                print('snowball', snowball_stem)
                vectors.append(model.get_vector(snowball_stem, norm=normalise))
    
    if not vectors:
        return np.zeros(300)
    
    if pool_type == 'mean':
        return np.mean(vectors, axis=0)
    elif pool_type == 'max':
        return np.max(vectors, axis=0)
    elif pool_type == 'mult':
        result = np.ones(300)
        for vector in vectors:
            result *= vector
        return result
    else:
        raise ValueError("Invalid pool_type. Choose either 'mean' or 'max' or 'mult'.")

# specific function for computing reuseable variable for sif pooling
def precompute_sif_weights(model, a=1e-3):
    corpus_total_words = sum(model.get_vecattr(word, 'count') for word in model.key_to_index)
    word_weights = {word: a / (a + model.get_vecattr(word, 'count') / corpus_total_words) for word in model.key_to_index}
    return word_weights, corpus_total_words

def transform_tokens_to_w2v_no_stems(string, model, pool_type='mean', normalise=False, word_weights=None, corpus_total_words=None):
    print('string:', string)
    vectors = []
    legit_tokens = []
    stops = set(stopwords.words('english'))
    original_tokens = tokenize(string)
    print('original tokens:', original_tokens)
    
    cleaned_tokens = [w for w in original_tokens if len(w) > 1 and w.isalpha() and w not in stops]
    print('cleaned:',cleaned_tokens)
    for token in cleaned_tokens:
        if token in model.key_to_index:
            legit_tokens.append(token)
            vectors.append(model.get_vector(token, norm=normalise))

    if not vectors:
        return np.zeros(300)

    if pool_type == 'mean':
        return np.mean(vectors, axis=0)
    elif pool_type == 'max':
        return np.max(vectors, axis=0)
    elif pool_type == 'mult':
        result = np.ones(300)
        for vector in vectors:
            result *= vector
        return result
    elif pool_type == 'sif':
        if word_weights is None or corpus_total_words is None:
            raise ValueError("Word weights and corpus total words must be provided for SIF pooling.")

        # Compute the weighted average of word vectors
        weighted_average = np.zeros(300)
        word_weights_sum = sum(word_weights[token] for token in legit_tokens)
        for token, vector in zip(legit_tokens, vectors):
            weighted_average += word_weights[token] * vector
        weighted_average /= word_weights_sum

        # Perform common component removal
        pc = np.mean(vectors, axis=0)
        weighted_average -= np.dot(weighted_average, pc) * pc

        return weighted_average
    else:
        raise ValueError("Invalid pool_type. Choose either 'mean', 'max', 'mult', or 'sif'.")

# %%
# custom dataset for handling the data trasnformation and with dataloader handling batching

class CustomPropagandaDataset_vanilla(Dataset):
    def __init__(self,df, model, stems=False, norm = False, pool = 'mean'):
        self.word_weights, self.corpus_total_words = precompute_sif_weights(model)

        self.stems = stems
        self.labels=torch.tensor([label for label in df['propaganda']])
        
        if self.stems==True:
            self.texts=torch.tensor([transform_tokens_to_w2v_with_stems(string, model, normalise = norm, pool_type=pool) for string in df['original_without_snip_tags']])
        else:
            self.texts=torch.tensor([transform_tokens_to_w2v_no_stems(string, model, normalise = norm, pool_type=pool, word_weights=self.word_weights, corpus_total_words=self.corpus_total_words) for string in df['original_without_snip_tags']])
        
    def classes(self):
        return self.labels
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self,idx):
        texts=self.texts[idx]
        y=self.labels[idx]
        return texts,y

# %%
# define the NN

class Custom_MLP_W2V(nn.Module):
    def __init__(self, dropout=0.5, num_classes=2): 
        super().__init__()
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.linear_1 = nn.Linear(300, 128)
        self.bn1 = nn.BatchNorm1d(128)  
        self.linear_2 = nn.Linear(128, 128)
        self.bn2 = nn.BatchNorm1d(128)  
        self.linear_3 = nn.Linear(128, num_classes)

    def forward(self, inputs):
        x = self.linear_1(inputs)
        x = self.bn1(x)  
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear_2(x)
        x = self.bn2(x)  
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear_3(x)
        return x

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cpu

# %%
# define hyperparamaters for experimentation/refinement

epochs =50
n_classes = 2
bn = 100
lr = 5e-4
stem_v = False
pool_v = 'mean'
norm_v = True
dr = 0.5




for pool_v in ['mean']: # this first line can be used to iterate through different hyperparamater settings

    # initialise datasets
    train_data = CustomPropagandaDataset_vanilla(train_df, my_model, stems=stem_v, norm = norm_v, pool=pool_v)
    val_data = CustomPropagandaDataset_vanilla(val_df, my_model, stems=stem_v, norm = norm_v, pool=pool_v)
    # initialise dataloaders
    train_dataloader=torch.utils.data.DataLoader(train_data,batch_size=bn,shuffle=True)
    val_dataloader=torch.utils.data.DataLoader(val_data,batch_size=bn)

    # initialise model instance, loss and optimiser
    model=Custom_MLP_W2V(num_classes=n_classes, dropout=dr).to(device)
    criterion=nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(params=model.parameters(), lr=lr)

    # for accumulating data for plotting later
    train_acc_list = []
    train_loss_list = []
    val_acc_list = []
    val_loss_list = []

    # for tracking best performance
    best_val_acc = 0
    best_epoch = 0
    best_model_state = None
    
    # unique id for saving data
    model_id = str(uuid.uuid4())

    # beggining of training iteration
    for epoch_num in range(epochs):

        total_acc_train=0
        total_loss_train=0
        model.train()
        # training loop
        for train_input,train_label in train_dataloader:

            train_input = train_input.to(device).float()
            train_label = train_label.to(device)
            output_1=model(train_input)

            batch_loss_1=criterion(output_1,train_label)

            total_loss_train += batch_loss_1.item()

            acc=(output_1.argmax(dim=1)==train_label).sum().item()
            total_acc_train+=acc

            model.zero_grad()
            batch_loss_1.backward()
            optimizer.step()

        total_acc_val=0
        total_loss_val=0

        y_true = []
        y_pred = []
        model.eval()
        # validation loop
        with torch.no_grad():
            for val_input,val_label in val_dataloader:

                val_input = val_input.to(device).float()
                val_label = val_label.to(device)

                output_2=model(val_input)

                batch_loss_2=criterion(output_2,val_label)

                total_loss_val+=batch_loss_2.item()

                acc=(output_2.argmax(dim=1)==val_label).sum().item()
                total_acc_val+=acc

                # for scoring
                predicted = output_2.argmax(dim=1)
                y_true.extend(val_label.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())
        
        train_acc = total_acc_train / len(train_data)
        train_loss = total_loss_train / len(train_data)
        val_acc = total_acc_val / len(val_data)
        val_loss = total_loss_val / len(val_data)

        train_acc_list.append(train_acc)
        train_loss_list.append(train_loss)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)
        
        # print running performance
        print(f'Epochs: {epoch_num+1} | Train Loss: {total_loss_train / len(train_data):.3f} | Train Accuracy: {total_acc_train/len(train_data):.3f}')
        print(f'Val loss: {total_loss_val/len(val_data):.3f} | Val Accuracy: {total_acc_val / len(val_data):.3f}')
        if val_acc > best_val_acc:
            best_epoch = epoch_num
            y_true_best = y_true.copy()
            y_pred_best = y_pred.copy()
            best_val_acc = val_acc
            best_model_state = model.state_dict()

        if epoch_num == epochs-1:
            print(f'______{model_id}______')
            print(f'LR: {lr} FINAL ACC = {total_acc_val / len(val_data):.3f}')
            print(f'LR: {lr} BEST ACC = {best_val_acc:.3f}')
            print('____________')
            
    # accuracy and loss curves over epochs
    epochs_range = range(1, epochs+1)

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, train_acc_list, label='Training Accuracy')
    plt.plot(epochs_range, val_acc_list, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.ylim(0, 1)  # Set y-axis limits from 0 to 1 for accuracy
    plt.title(f'Accuracy for lr {lr}, batch size {bn}, best ac: {best_val_acc:.2f}')

    # plt.subplot(1, 2, 2)
    # plt.plot(epochs_range, train_loss_list, label='Training Loss')
    # plt.plot(epochs_range, val_loss_list, label='Validation Loss')
    # plt.xlabel('Epochs')
    # plt.ylabel('Loss')
    # plt.legend(loc='upper right')
    # plt.title('Loss Curves')

    plt.tight_layout()
    plt.show()
    
    # analysis of model at best performing
    cm = confusion_matrix(y_true_best, y_pred_best)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot()

    # Compute precision, recall, F1-score, and other metrics for the best model
    report = classification_report(y_true_best, y_pred_best, target_names=['class 0', 'class 1'])
    print('Classification Report:')
    print(report)

    results_dict = {
        'model_id': model_id,
        'train_accuracy': train_acc_list,
        'train_loss': train_loss_list,
        'val_accuracy': val_acc_list,
        'val_loss': val_loss_list,
        'hyperparameters': {
            'learning_rate': lr,
            'num_epochs': epochs,
            'batch_size': bn,
            'stem_v':stem_v,
            'pool_v':pool_v,
            'norm_v':norm_v,
            'dropout_rate': dr,
        },
        'results': {
            "classes": n_classes,
            "last_acc": val_acc_list[-1],
            'best_acc': best_val_acc,
            'best_acc_epoch': best_epoch,
            'confusion_matrix': cm.tolist(),
            'classification_report': report
        }
    }


    # Save the results dictionary as a JSON file with the model ID
    results_filename = f'./results/w2v_binary/w2v_binary_results_{model_id}.json'
    with open(results_filename, 'w') as f:
        json.dump(results_dict, f, indent=4)
# Out:
# string: No,  he  will not be confirmed.
# original tokens: ['No', ',', 'he', 'will', 'not', 'be', 'confirmed', '.']
# cleaned: ['No', 'confirmed']
# string: This declassification effort  won’t make things any worse than they are for President Trump.
# original tokens: ['This', 'declassification', 'effort', 'won', '’', 't', 'make', 'things', 'any', 'worse', 'than', 'they', 'are', 'for', 'President', 'Trump', '.']
# cleaned: ['This', 'declassification', 'effort', 'make', 'things', 'worse', 'President', 'Trump']
# string: "The Obama administration misled the  American people  and Congress because they were desperate to get a deal with Iran," said Sen.
# original tokens: ['``', 'The', 'Obama', 'administration', 'misled', 'the', 'American', 'people', 'and', 'Congress', 'because', 'they', 'were', 'desperate', 'to', 'get', 'a', 'deal', 'with', 'Iran', ',', "''", 'said', 'Sen', '.']
# cleaned: ['The', 'Obama', 'administration', 'misled', 'American', 'people', 'Congress', 'desperate', 'get', 'deal', 'Iran', 'said', 'Sen']
# string: “It looks like we’re capturing the demise of this dark vortex,  and  it’s different from what well-known studies led us to expect,” said Michael H. Wong of the University of California at Berkeley says.
# original tokens: ['“', 'It', 'looks', 'like', 'we', '’', 're', 'capturing', 'the', 'demise', 'of', 'this', 'dark', 'vortex', ',', 'and', 'it', '’', 's', 'different', 'from', 'what', 'well-known', 'studies', 'led', 'us', 'to', 'expect', ',', '”', 'said', 'Michael', 'H.', 'Wong', 'of', 'the', 'University', 'of', 'California', 'at', 'Berkeley', 'says', '.']
# cleaned: ['It', 'looks', 'like', 'capturing', 'demise', 'dark', 'vortex', 'different', 'studies', 'led', 'us', 'expect', 'said', 'Michael', 'Wong', 'University', 'California', 'Berkeley', 'says']
# string:  Location: Westerville, Ohio
# original tokens: ['Location', ':', 'Westerville', ',', 'Ohio']
# cleaned: ['Location', 'Westerville', 'Ohio']
# string: Hitler  annihilated  400,000 Germans who were handicapped or suffered from chronic diseases.
# original tokens: ['Hitler', 'annihilated', '400,000', 'Germans', 'who', 'were', 'handicapped', 'or', 'suffered', 'from', 'chronic', 'diseases', '.']
# cleaned: ['Hitler', 'annihilated', 'Germans', 'handicapped', 'suffered', 'chronic', 'diseases']
# string: A federal judge on Monday ordered U.S. immigration officials to delay any efforts to deport 51 Indonesians living illegally in New Hampshire so the group can have time  to argue that changing conditions in that country would make it dangerous to return... Federal law gives authority over immigration matters to the executive  branch, not the courts.
# original tokens: ['A', 'federal', 'judge', 'on', 'Monday', 'ordered', 'U.S.', 'immigration', 'officials', 'to', 'delay', 'any', 'efforts', 'to', 'deport', '51', 'Indonesians', 'living', 'illegally', 'in', 'New', 'Hampshire', 'so', 'the', 'group', 'can', 'have', 'time', 'to', 'argue', 'that', 'changing', 'conditions', 'in', 'that', 'country', 'would', 'make', 'it', 'dangerous', 'to', 'return', '...', 'Federal', 'law', 'gives', 'authority', 'over', 'immigration', 'matters', 'to', 'the', 'executive', 'branch', ',', 'not', 'the', 'courts', '.']
# cleaned: ['federal', 'judge', 'Monday', 'ordered', 'immigration', 'officials', 'delay', 'efforts', 'deport', 'Indonesians', 'living', 'illegally', 'New', 'Hampshire', 'group', 'time', 'argue', 'changing', 'conditions', 'country', 'would', 'make', 'dangerous', 'return', 'Federal', 'law', 'gives', 'authority', 'immigration', 'matters', 'executive', 'branch', 'courts']
# string:  Kirstjen Nielsen (@SecNielsen)  November 19, 2018
# original tokens: ['Kirstjen', 'Nielsen', '(', '@', 'SecNielsen', ')', 'November', '19', ',', '2018']
# cleaned: ['Kirstjen', 'Nielsen', 'SecNielsen', 'November']
# string: As noted above, at this point literally every piece of  so-called evidence  put forth by authorities and then regurgitated by the mainstream media cannot be trusted and should be considered as disinformation until proven otherwise.
# original tokens: ['As', 'noted', 'above', ',', 'at', 'this', 'point', 'literally', 'every', 'piece', 'of', 'so-called', 'evidence', 'put', 'forth', 'by', 'authorities', 'and', 'then', 'regurgitated', 'by', 'the', 'mainstream', 'media', 'can', 'not', 'be', 'trusted', 'and', 'should', 'be', 'considered', 'as', 'disinformation', 'until', 'proven', 'otherwise', '.']
# cleaned: ['As', 'noted', 'point', 'literally', 'every', 'piece', 'evidence', 'put', 'forth', 'authorities', 'regurgitated', 'mainstream', 'media', 'trusted', 'considered', 'disinformation', 'proven', 'otherwise']
# string: Britain doesn't need more hate even just for a  few days."
# original tokens: ['Britain', 'does', "n't", 'need', 'more', 'hate', 'even', 'just', 'for', 'a', 'few', 'days', '.', "''"]
# cleaned: ['Britain', 'need', 'hate', 'even', 'days']
# string: His account was suspended for violating Twitter’s rules relating to “ hateful conduct .” It is "hateful conduct", apparently, to reference what Islamic texts themselves say.
# original tokens: ['His', 'account', 'was', 'suspended', 'for', 'violating', 'Twitter', '’', 's', 'rules', 'relating', 'to', '“', 'hateful', 'conduct', '.', '”', 'It', 'is', '``', 'hateful', 'conduct', "''", ',', 'apparently', ',', 'to', 'reference', 'what', 'Islamic', 'texts', 'themselves', 'say', '.']
# cleaned: ['His', 'account', 'suspended', 'violating', 'Twitter', 'rules', 'relating', 'hateful', 'conduct', 'It', 'hateful', 'conduct', 'apparently', 'reference', 'Islamic', 'texts', 'say']
# string: Ironically, even in doing this he is  likely to fail to  satisfy Muslims, or anyone.
# original tokens: ['Ironically', ',', 'even', 'in', 'doing', 'this', 'he', 'is', 'likely', 'to', 'fail', 'to', 'satisfy', 'Muslims', ',', 'or', 'anyone', '.']
# cleaned: ['Ironically', 'even', 'likely', 'fail', 'satisfy', 'Muslims', 'anyone']
# string: A couple of seemingly unrelated events this past week  point to Iran’s positioning itself for more aggressive military actions that could place U.S. forces in harm’s way .
# original tokens: ['A', 'couple', 'of', 'seemingly', 'unrelated', 'events', 'this', 'past', 'week', 'point', 'to', 'Iran', '’', 's', 'positioning', 'itself', 'for', 'more', 'aggressive', 'military', 'actions', 'that', 'could', 'place', 'U.S.', 'forces', 'in', 'harm', '’', 's', 'way', '.']
# cleaned: ['couple', 'seemingly', 'unrelated', 'events', 'past', 'week', 'point', 'Iran', 'positioning', 'aggressive', 'military', 'actions', 'could', 'place', 'forces', 'harm', 'way']
# string: During the term of the Assassination  Records Review Board in the 1990s, the  CIA decided to keep these particular records secret for another 25 years.
# original tokens: ['During', 'the', 'term', 'of', 'the', 'Assassination', 'Records', 'Review', 'Board', 'in', 'the', '1990s', ',', 'the', 'CIA', 'decided', 'to', 'keep', 'these', 'particular', 'records', 'secret', 'for', 'another', '25', 'years', '.']
# cleaned: ['During', 'term', 'Assassination', 'Records', 'Review', 'Board', 'CIA', 'decided', 'keep', 'particular', 'records', 'secret', 'another', 'years']
# string: Trump has expelled  more  Russian diplomats and sanctioned more Russian oligarchs than [Obama] has.
# original tokens: ['Trump', 'has', 'expelled', 'more', 'Russian', 'diplomats', 'and', 'sanctioned', 'more', 'Russian', 'oligarchs', 'than', '[', 'Obama', ']', 'has', '.']
# cleaned: ['Trump', 'expelled', 'Russian', 'diplomats', 'sanctioned', 'Russian', 'oligarchs', 'Obama']
# string: President Trump ordered that the relevant documents be released by the Office of the Director of National Intelligence (ODNI) and the Justice Department “[a]t the request of a number of committees of Congress, and for  reasons of transparency,” read a statement issued by White House  Press Secretary Sarah Huckabee Sanders.
# original tokens: ['President', 'Trump', 'ordered', 'that', 'the', 'relevant', 'documents', 'be', 'released', 'by', 'the', 'Office', 'of', 'the', 'Director', 'of', 'National', 'Intelligence', '(', 'ODNI', ')', 'and', 'the', 'Justice', 'Department', '“', '[', 'a', ']', 't', 'the', 'request', 'of', 'a', 'number', 'of', 'committees', 'of', 'Congress', ',', 'and', 'for', 'reasons', 'of', 'transparency', ',', '”', 'read', 'a', 'statement', 'issued', 'by', 'White', 'House', 'Press', 'Secretary', 'Sarah', 'Huckabee', 'Sanders', '.']
# cleaned: ['President', 'Trump', 'ordered', 'relevant', 'documents', 'released', 'Office', 'Director', 'National', 'Intelligence', 'ODNI', 'Justice', 'Department', 'request', 'number', 'committees', 'Congress', 'reasons', 'transparency', 'read', 'statement', 'issued', 'White', 'House', 'Press', 'Secretary', 'Sarah', 'Huckabee', 'Sanders']
# string: The newspaper added that Manafort’s visit was  not  entered into the embassy’s log book and cited a source as saying Manafort left after 40 minutes.
# original tokens: ['The', 'newspaper', 'added', 'that', 'Manafort', '’', 's', 'visit', 'was', 'not', 'entered', 'into', 'the', 'embassy', '’', 's', 'log', 'book', 'and', 'cited', 'a', 'source', 'as', 'saying', 'Manafort', 'left', 'after', '40', 'minutes', '.']
# cleaned: ['The', 'newspaper', 'added', 'Manafort', 'visit', 'entered', 'embassy', 'log', 'book', 'cited', 'source', 'saying', 'Manafort', 'left', 'minutes']
# string: “We are now doing a  recount, so  we want to make sure you let your vote be counted,” Dixon quoted from the voicemail.
# original tokens: ['“', 'We', 'are', 'now', 'doing', 'a', 'recount', ',', 'so', 'we', 'want', 'to', 'make', 'sure', 'you', 'let', 'your', 'vote', 'be', 'counted', ',', '”', 'Dixon', 'quoted', 'from', 'the', 'voicemail', '.']
# cleaned: ['We', 'recount', 'want', 'make', 'sure', 'let', 'vote', 'counted', 'Dixon', 'quoted', 'voicemail']
# string:  But who authorized this strategic commitment , of indefinite duration, in Syria, when near two decades in Afghanistan have failed to secure that nation against the return of al-Qaida and ISIS?
# original tokens: ['But', 'who', 'authorized', 'this', 'strategic', 'commitment', ',', 'of', 'indefinite', 'duration', ',', 'in', 'Syria', ',', 'when', 'near', 'two', 'decades', 'in', 'Afghanistan', 'have', 'failed', 'to', 'secure', 'that', 'nation', 'against', 'the', 'return', 'of', 'al-Qaida', 'and', 'ISIS', '?']
# cleaned: ['But', 'authorized', 'strategic', 'commitment', 'indefinite', 'duration', 'Syria', 'near', 'two', 'decades', 'Afghanistan', 'failed', 'secure', 'nation', 'return', 'ISIS']
# string: Outside of specialists and seekers,  the only reason why there is general interest in the Qur’an among non-Muslims is to seek an answer to the question of whether or not it justifies and encourages Islamic terrorism .
# original tokens: ['Outside', 'of', 'specialists', 'and', 'seekers', ',', 'the', 'only', 'reason', 'why', 'there', 'is', 'general', 'interest', 'in', 'the', 'Qur', '’', 'an', 'among', 'non-Muslims', 'is', 'to', 'seek', 'an', 'answer', 'to', 'the', 'question', 'of', 'whether', 'or', 'not', 'it', 'justifies', 'and', 'encourages', 'Islamic', 'terrorism', '.']
# cleaned: ['Outside', 'specialists', 'seekers', 'reason', 'general', 'interest', 'Qur', 'among', 'seek', 'answer', 'question', 'whether', 'justifies', 'encourages', 'Islamic', 'terrorism']
# string:  We must ask ourselves why this hasn’t happened .
# original tokens: ['We', 'must', 'ask', 'ourselves', 'why', 'this', 'hasn', '’', 't', 'happened', '.']
# cleaned: ['We', 'must', 'ask', 'happened']
# string: We’ve caught on to his  sneaky  synodal tactics.
# original tokens: ['We', '’', 've', 'caught', 'on', 'to', 'his', 'sneaky', 'synodal', 'tactics', '.']
# cleaned: ['We', 'caught', 'sneaky', 'synodal', 'tactics']
# string: This is an outrage, but it is common nationwide: the Daily Caller News Foundation reports that Mountain Ridge Middle School in West Virginia is “instructing junior high students to write the Islamic profession of faith ostensibly to practice calligraphy.” Students are made to write out the Shahada, which states: “There is no god but Allah, and Muhammad is the messenger of Allah.”This is exactly what I warned about in my book, Stop the Islamization of  America : A Practical Guide to the Resistance , in the chapter “The Mosqueing of the Public Schools.”In order to convert to Islam, one says the shahada.
# original tokens: ['This', 'is', 'an', 'outrage', ',', 'but', 'it', 'is', 'common', 'nationwide', ':', 'the', 'Daily', 'Caller', 'News', 'Foundation', 'reports', 'that', 'Mountain', 'Ridge', 'Middle', 'School', 'in', 'West', 'Virginia', 'is', '“', 'instructing', 'junior', 'high', 'students', 'to', 'write', 'the', 'Islamic', 'profession', 'of', 'faith', 'ostensibly', 'to', 'practice', 'calligraphy.', '”', 'Students', 'are', 'made', 'to', 'write', 'out', 'the', 'Shahada', ',', 'which', 'states', ':', '“', 'There', 'is', 'no', 'god', 'but', 'Allah', ',', 'and', 'Muhammad', 'is', 'the', 'messenger', 'of', 'Allah.', '”', 'This', 'is', 'exactly', 'what', 'I', 'warned', 'about', 'in', 'my', 'book', ',', 'Stop', 'the', 'Islamization', 'of', 'America', ':', 'A', 'Practical', 'Guide', 'to', 'the', 'Resistance', ',', 'in', 'the', 'chapter', '“', 'The', 'Mosqueing', 'of', 'the', 'Public', 'Schools.', '”', 'In', 'order', 'to', 'convert', 'to', 'Islam', ',', 'one', 'says', 'the', 'shahada', '.']
# cleaned: ['This', 'outrage', 'common', 'nationwide', 'Daily', 'Caller', 'News', 'Foundation', 'reports', 'Mountain', 'Ridge', 'Middle', 'School', 'West', 'Virginia', 'instructing', 'junior', 'high', 'students', 'write', 'Islamic', 'profession', 'faith', 'ostensibly', 'practice', 'Students', 'made', 'write', 'Shahada', 'states', 'There', 'god', 'Allah', 'Muhammad', 'messenger', 'This', 'exactly', 'warned', 'book', 'Stop', 'Islamization', 'America', 'Practical', 'Guide', 'Resistance', 'chapter', 'The', 'Mosqueing', 'Public', 'In', 'order', 'convert', 'Islam', 'one', 'says', 'shahada']
# string: This  is the point about the McCarrick scandal that even  religious commentators tend to overlook.
# original tokens: ['This', 'is', 'the', 'point', 'about', 'the', 'McCarrick', 'scandal', 'that', 'even', 'religious', 'commentators', 'tend', 'to', 'overlook', '.']
# cleaned: ['This', 'point', 'McCarrick', 'scandal', 'even', 'religious', 'commentators', 'tend', 'overlook']
# string: Kavanaugh denies the  accusations.
# original tokens: ['Kavanaugh', 'denies', 'the', 'accusations', '.']
# cleaned: ['Kavanaugh', 'denies', 'accusations']
# string: The time limit of the Commission’s members was allowed to lapse without renewal and though it was not dissolved  formally the Commission has  ceased to function with no word of any plan to revive it.
# original tokens: ['The', 'time', 'limit', 'of', 'the', 'Commission', '’', 's', 'members', 'was', 'allowed', 'to', 'lapse', 'without', 'renewal', 'and', 'though', 'it', 'was', 'not', 'dissolved', 'formally', 'the', 'Commission', 'has', 'ceased', 'to', 'function', 'with', 'no', 'word', 'of', 'any', 'plan', 'to', 'revive', 'it', '.']
# cleaned: ['The', 'time', 'limit', 'Commission', 'members', 'allowed', 'lapse', 'without', 'renewal', 'though', 'dissolved', 'formally', 'Commission', 'ceased', 'function', 'word', 'plan', 'revive']
# string: Bob Mueller is totally conflicted, and his 17 Angry Democrats that are doing his dirty work are  a disgrace to USA !” Trump wrote.
# original tokens: ['Bob', 'Mueller', 'is', 'totally', 'conflicted', ',', 'and', 'his', '17', 'Angry', 'Democrats', 'that', 'are', 'doing', 'his', 'dirty', 'work', 'are', 'a', 'disgrace', 'to', 'USA', '!', '”', 'Trump', 'wrote', '.']
# cleaned: ['Bob', 'Mueller', 'totally', 'conflicted', 'Angry', 'Democrats', 'dirty', 'work', 'disgrace', 'USA', 'Trump', 'wrote']
# string: “Let me get this straight: this is [a] statement about [a] secret letter regarding a secret matter and an  unidentified person.
# original tokens: ['“', 'Let', 'me', 'get', 'this', 'straight', ':', 'this', 'is', '[', 'a', ']', 'statement', 'about', '[', 'a', ']', 'secret', 'letter', 'regarding', 'a', 'secret', 'matter', 'and', 'an', 'unidentified', 'person', '.']
# cleaned: ['Let', 'get', 'straight', 'statement', 'secret', 'letter', 'regarding', 'secret', 'matter', 'unidentified', 'person']
# string: Average age:  65
# original tokens: ['Average', 'age', ':', '65']
# cleaned: ['Average', 'age']
# string: Present problems: ageing of the  sisters and a lack of  vocations.
# original tokens: ['Present', 'problems', ':', 'ageing', 'of', 'the', 'sisters', 'and', 'a', 'lack', 'of', 'vocations', '.']
# cleaned: ['Present', 'problems', 'ageing', 'sisters', 'lack', 'vocations']
# string: He stood up to challenge  the fact that the CIA was about to  hand over leadership to a person who had been in charge of torture.
# original tokens: ['He', 'stood', 'up', 'to', 'challenge', 'the', 'fact', 'that', 'the', 'CIA', 'was', 'about', 'to', 'hand', 'over', 'leadership', 'to', 'a', 'person', 'who', 'had', 'been', 'in', 'charge', 'of', 'torture', '.']
# cleaned: ['He', 'stood', 'challenge', 'fact', 'CIA', 'hand', 'leadership', 'person', 'charge', 'torture']
# string: Hitler embodies one type of modern Western  annihilation .
# original tokens: ['Hitler', 'embodies', 'one', 'type', 'of', 'modern', 'Western', 'annihilation', '.']
# cleaned: ['Hitler', 'embodies', 'one', 'type', 'modern', 'Western', 'annihilation']
# string: He was previously removed to Mexico in 2009 after he illegally entered the United States through Laredo,  Texas.
# original tokens: ['He', 'was', 'previously', 'removed', 'to', 'Mexico', 'in', '2009', 'after', 'he', 'illegally', 'entered', 'the', 'United', 'States', 'through', 'Laredo', ',', 'Texas', '.']
# cleaned: ['He', 'previously', 'removed', 'Mexico', 'illegally', 'entered', 'United', 'States', 'Laredo', 'Texas']
# string:  The economic fund [of the federation] is nourished by the free donations of the monasteries, by the donations of benefactors, and by revenues deriving from the alienation of the assets of suppressed monasteries, as established  by the present Instruction.
# original tokens: ['The', 'economic', 'fund', '[', 'of', 'the', 'federation', ']', 'is', 'nourished', 'by', 'the', 'free', 'donations', 'of', 'the', 'monasteries', ',', 'by', 'the', 'donations', 'of', 'benefactors', ',', 'and', 'by', 'revenues', 'deriving', 'from', 'the', 'alienation', 'of', 'the', 'assets', 'of', 'suppressed', 'monasteries', ',', 'as', 'established', 'by', 'the', 'present', 'Instruction', '.']
# cleaned: ['The', 'economic', 'fund', 'federation', 'nourished', 'free', 'donations', 'monasteries', 'donations', 'benefactors', 'revenues', 'deriving', 'alienation', 'assets', 'suppressed', 'monasteries', 'established', 'present', 'Instruction']
# string: Kritarch Saris thought she knew better and has been running a deliberate campaign to prevent the deportation of these Chinese  illegal aliens .
# original tokens: ['Kritarch', 'Saris', 'thought', 'she', 'knew', 'better', 'and', 'has', 'been', 'running', 'a', 'deliberate', 'campaign', 'to', 'prevent', 'the', 'deportation', 'of', 'these', 'Chinese', 'illegal', 'aliens', '.']
# cleaned: ['Kritarch', 'Saris', 'thought', 'knew', 'better', 'running', 'deliberate', 'campaign', 'prevent', 'deportation', 'Chinese', 'illegal', 'aliens']
# string: But now, the  sonic attacks  have progressed beyond Cuba.
# original tokens: ['But', 'now', ',', 'the', 'sonic', 'attacks', 'have', 'progressed', 'beyond', 'Cuba', '.']
# cleaned: ['But', 'sonic', 'attacks', 'progressed', 'beyond', 'Cuba']
# string: Thousands of  U.S. dead , tens of thousands of wounded, trillions of dollars sunk, and a Mideast awash in blood from Afghanistan to Iraq, Libya, Syria and Yemen, with millions uprooted and homeless.
# original tokens: ['Thousands', 'of', 'U.S.', 'dead', ',', 'tens', 'of', 'thousands', 'of', 'wounded', ',', 'trillions', 'of', 'dollars', 'sunk', ',', 'and', 'a', 'Mideast', 'awash', 'in', 'blood', 'from', 'Afghanistan', 'to', 'Iraq', ',', 'Libya', ',', 'Syria', 'and', 'Yemen', ',', 'with', 'millions', 'uprooted', 'and', 'homeless', '.']
# cleaned: ['Thousands', 'dead', 'tens', 'thousands', 'wounded', 'trillions', 'dollars', 'sunk', 'Mideast', 'awash', 'blood', 'Afghanistan', 'Iraq', 'Libya', 'Syria', 'Yemen', 'millions', 'uprooted', 'homeless']
# string: (The Dutch media now claim that one of them doesn’t depict  Muslim  migrants being violent, as was claimed.
# original tokens: ['(', 'The', 'Dutch', 'media', 'now', 'claim', 'that', 'one', 'of', 'them', 'doesn', '’', 't', 'depict', 'Muslim', 'migrants', 'being', 'violent', ',', 'as', 'was', 'claimed', '.']
# cleaned: ['The', 'Dutch', 'media', 'claim', 'one', 'depict', 'Muslim', 'migrants', 'violent', 'claimed']
# string:  Either you stand with BDS, Hamas, blood libels and those who want to destroy Israel or with Jews .
# original tokens: ['Either', 'you', 'stand', 'with', 'BDS', ',', 'Hamas', ',', 'blood', 'libels', 'and', 'those', 'who', 'want', 'to', 'destroy', 'Israel', 'or', 'with', 'Jews', '.']
# cleaned: ['Either', 'stand', 'BDS', 'Hamas', 'blood', 'libels', 'want', 'destroy', 'Israel', 'Jews']
# string:  Putting aside freedom of speech, the persecution of this man has been something that should horrify all free-thinking people. If it doesn’t horrify us, then we have surrendered something very valuable .
# original tokens: ['Putting', 'aside', 'freedom', 'of', 'speech', ',', 'the', 'persecution', 'of', 'this', 'man', 'has', 'been', 'something', 'that', 'should', 'horrify', 'all', 'free-thinking', 'people', '.', 'If', 'it', 'doesn', '’', 't', 'horrify', 'us', ',', 'then', 'we', 'have', 'surrendered', 'something', 'very', 'valuable', '.']
# cleaned: ['Putting', 'aside', 'freedom', 'speech', 'persecution', 'man', 'something', 'horrify', 'people', 'If', 'horrify', 'us', 'surrendered', 'something', 'valuable']
# string: She  is  calling for an Israeli/Palestinian state that would not be a Jewish State or a homeland for the Jewish people, but a federation in which Palestinians would soon overwhelm Jews demographically.
# original tokens: ['She', 'is', 'calling', 'for', 'an', 'Israeli/Palestinian', 'state', 'that', 'would', 'not', 'be', 'a', 'Jewish', 'State', 'or', 'a', 'homeland', 'for', 'the', 'Jewish', 'people', ',', 'but', 'a', 'federation', 'in', 'which', 'Palestinians', 'would', 'soon', 'overwhelm', 'Jews', 'demographically', '.']
# cleaned: ['She', 'calling', 'state', 'would', 'Jewish', 'State', 'homeland', 'Jewish', 'people', 'federation', 'Palestinians', 'would', 'soon', 'overwhelm', 'Jews', 'demographically']
# string: “Motive a mystery in car explosion at Travis Air Force Base,” by Phil Willon, Los Angeles Times, March 23,  2018:
# original tokens: ['“', 'Motive', 'a', 'mystery', 'in', 'car', 'explosion', 'at', 'Travis', 'Air', 'Force', 'Base', ',', '”', 'by', 'Phil', 'Willon', ',', 'Los', 'Angeles', 'Times', ',', 'March', '23', ',', '2018', ':']
# cleaned: ['Motive', 'mystery', 'car', 'explosion', 'Travis', 'Air', 'Force', 'Base', 'Phil', 'Willon', 'Los', 'Angeles', 'Times', 'March']
# string: Whosoever shall shed man’s blood, his blood shall be shed: for man was made to the image of God.” In other words,  from that point in history lawful killing in atonement for taking the life of another is sanctioned by God .
# original tokens: ['Whosoever', 'shall', 'shed', 'man', '’', 's', 'blood', ',', 'his', 'blood', 'shall', 'be', 'shed', ':', 'for', 'man', 'was', 'made', 'to', 'the', 'image', 'of', 'God.', '”', 'In', 'other', 'words', ',', 'from', 'that', 'point', 'in', 'history', 'lawful', 'killing', 'in', 'atonement', 'for', 'taking', 'the', 'life', 'of', 'another', 'is', 'sanctioned', 'by', 'God', '.']
# cleaned: ['Whosoever', 'shall', 'shed', 'man', 'blood', 'blood', 'shall', 'shed', 'man', 'made', 'image', 'In', 'words', 'point', 'history', 'lawful', 'killing', 'atonement', 'taking', 'life', 'another', 'sanctioned', 'God']
# string: Elizabeth Yore is an attorney  who has investigated clerical sex  abuse cases.
# original tokens: ['Elizabeth', 'Yore', 'is', 'an', 'attorney', 'who', 'has', 'investigated', 'clerical', 'sex', 'abuse', 'cases', '.']
# cleaned: ['Elizabeth', 'Yore', 'attorney', 'investigated', 'clerical', 'sex', 'abuse', 'cases']
# string: Thanks to President Trump and the CIA’s decision  to continue keeping 98 percent of the CIA’s decades-long secret records secret from the American people , the CIA’s cunning cover-up of the JFK assassination continues to work brilliantly today.
# original tokens: ['Thanks', 'to', 'President', 'Trump', 'and', 'the', 'CIA', '’', 's', 'decision', 'to', 'continue', 'keeping', '98', 'percent', 'of', 'the', 'CIA', '’', 's', 'decades-long', 'secret', 'records', 'secret', 'from', 'the', 'American', 'people', ',', 'the', 'CIA', '’', 's', 'cunning', 'cover-up', 'of', 'the', 'JFK', 'assassination', 'continues', 'to', 'work', 'brilliantly', 'today', '.']
# cleaned: ['Thanks', 'President', 'Trump', 'CIA', 'decision', 'continue', 'keeping', 'percent', 'CIA', 'secret', 'records', 'secret', 'American', 'people', 'CIA', 'cunning', 'JFK', 'assassination', 'continues', 'work', 'brilliantly', 'today']
# string: Frings, Archbishop of  Cologne.
# original tokens: ['Frings', ',', 'Archbishop', 'of', 'Cologne', '.']
# cleaned: ['Frings', 'Archbishop', 'Cologne']
# string: Where is that authorized in  our Constitution ?
# original tokens: ['Where', 'is', 'that', 'authorized', 'in', 'our', 'Constitution', '?']
# cleaned: ['Where', 'authorized', 'Constitution']
# string: While the establishment continues to push the notion that  a couple hundred thousand dollars of ad spends and some Russian bots on Facebook swayed the election to Donald Trump , more proof of real “collusion” between Google and the Hillary Clinton campaign has been uncovered.
# original tokens: ['While', 'the', 'establishment', 'continues', 'to', 'push', 'the', 'notion', 'that', 'a', 'couple', 'hundred', 'thousand', 'dollars', 'of', 'ad', 'spends', 'and', 'some', 'Russian', 'bots', 'on', 'Facebook', 'swayed', 'the', 'election', 'to', 'Donald', 'Trump', ',', 'more', 'proof', 'of', 'real', '“', 'collusion', '”', 'between', 'Google', 'and', 'the', 'Hillary', 'Clinton', 'campaign', 'has', 'been', 'uncovered', '.']
# cleaned: ['While', 'establishment', 'continues', 'push', 'notion', 'couple', 'hundred', 'thousand', 'dollars', 'ad', 'spends', 'Russian', 'bots', 'Facebook', 'swayed', 'election', 'Donald', 'Trump', 'proof', 'real', 'collusion', 'Google', 'Hillary', 'Clinton', 'campaign', 'uncovered']
# string: Britain took part in an investigation which determined that Julian was a political refugee and that  a great miscarriage of justice  had been imposed on him.
# original tokens: ['Britain', 'took', 'part', 'in', 'an', 'investigation', 'which', 'determined', 'that', 'Julian', 'was', 'a', 'political', 'refugee', 'and', 'that', 'a', 'great', 'miscarriage', 'of', 'justice', 'had', 'been', 'imposed', 'on', 'him', '.']
# cleaned: ['Britain', 'took', 'part', 'investigation', 'determined', 'Julian', 'political', 'refugee', 'great', 'miscarriage', 'justice', 'imposed']
# string: This is why it is so  heinous .”
# original tokens: ['This', 'is', 'why', 'it', 'is', 'so', 'heinous', '.', '”']
# cleaned: ['This', 'heinous']
# string:  The last-minute accusations from Christine Blasey Ford, a woman who claims that decades ago Kavanaugh groped her at a high school party, and Deborah Ramirez, who accused Kavanaugh of exposing himself to her at a frat party at Yale, are transparent acts of aggression against the judge and Republicans, one engineered by the Democrats .
# original tokens: ['The', 'last-minute', 'accusations', 'from', 'Christine', 'Blasey', 'Ford', ',', 'a', 'woman', 'who', 'claims', 'that', 'decades', 'ago', 'Kavanaugh', 'groped', 'her', 'at', 'a', 'high', 'school', 'party', ',', 'and', 'Deborah', 'Ramirez', ',', 'who', 'accused', 'Kavanaugh', 'of', 'exposing', 'himself', 'to', 'her', 'at', 'a', 'frat', 'party', 'at', 'Yale', ',', 'are', 'transparent', 'acts', 'of', 'aggression', 'against', 'the', 'judge', 'and', 'Republicans', ',', 'one', 'engineered', 'by', 'the', 'Democrats', '.']
# cleaned: ['The', 'accusations', 'Christine', 'Blasey', 'Ford', 'woman', 'claims', 'decades', 'ago', 'Kavanaugh', 'groped', 'high', 'school', 'party', 'Deborah', 'Ramirez', 'accused', 'Kavanaugh', 'exposing', 'frat', 'party', 'Yale', 'transparent', 'acts', 'aggression', 'judge', 'Republicans', 'one', 'engineered', 'Democrats']
# string: I said that  the reason I dropped the “J” word was because you haven’t in 40 years  (Romans 1:16).
# original tokens: ['I', 'said', 'that', 'the', 'reason', 'I', 'dropped', 'the', '“', 'J', '”', 'word', 'was', 'because', 'you', 'haven', '’', 't', 'in', '40', 'years', '(', 'Romans', '1:16', ')', '.']
# cleaned: ['said', 'reason', 'dropped', 'word', 'years', 'Romans']
# string: In a letter to the Australian prime minister, Malcolm Turnbull, Julian’s father, John Shipton, wrote: “I ask the prime minister  to do all within his power to return Julian home before Julian’s situation becomes an irreversible tragedy .” That is why this is such an urgent case of justice toward a single human being as well as a case of a journalistic organization’s right to function and our right to have the information it provides.
# original tokens: ['In', 'a', 'letter', 'to', 'the', 'Australian', 'prime', 'minister', ',', 'Malcolm', 'Turnbull', ',', 'Julian', '’', 's', 'father', ',', 'John', 'Shipton', ',', 'wrote', ':', '“', 'I', 'ask', 'the', 'prime', 'minister', 'to', 'do', 'all', 'within', 'his', 'power', 'to', 'return', 'Julian', 'home', 'before', 'Julian', '’', 's', 'situation', 'becomes', 'an', 'irreversible', 'tragedy', '.', '”', 'That', 'is', 'why', 'this', 'is', 'such', 'an', 'urgent', 'case', 'of', 'justice', 'toward', 'a', 'single', 'human', 'being', 'as', 'well', 'as', 'a', 'case', 'of', 'a', 'journalistic', 'organization', '’', 's', 'right', 'to', 'function', 'and', 'our', 'right', 'to', 'have', 'the', 'information', 'it', 'provides', '.']
# cleaned: ['In', 'letter', 'Australian', 'prime', 'minister', 'Malcolm', 'Turnbull', 'Julian', 'father', 'John', 'Shipton', 'wrote', 'ask', 'prime', 'minister', 'within', 'power', 'return', 'Julian', 'home', 'Julian', 'situation', 'becomes', 'irreversible', 'tragedy', 'That', 'urgent', 'case', 'justice', 'toward', 'single', 'human', 'well', 'case', 'journalistic', 'organization', 'right', 'function', 'right', 'information', 'provides']
# string: They practiced  sauvage  intercommunion.
# original tokens: ['They', 'practiced', 'sauvage', 'intercommunion', '.']
# cleaned: ['They', 'practiced', 'sauvage', 'intercommunion']
# string:  The  first version read:
# original tokens: ['The', 'first', 'version', 'read', ':']
# cleaned: ['The', 'first', 'version', 'read']
# string: Founded in 1974, The Foundation has grown to more than 600,000 members and supporters  and conducts many programs designed to better inform the public  about the consequences of gun control.
# original tokens: ['Founded', 'in', '1974', ',', 'The', 'Foundation', 'has', 'grown', 'to', 'more', 'than', '600,000', 'members', 'and', 'supporters', 'and', 'conducts', 'many', 'programs', 'designed', 'to', 'better', 'inform', 'the', 'public', 'about', 'the', 'consequences', 'of', 'gun', 'control', '.']
# cleaned: ['Founded', 'The', 'Foundation', 'grown', 'members', 'supporters', 'conducts', 'many', 'programs', 'designed', 'better', 'inform', 'public', 'consequences', 'gun', 'control']
# string: Even though Senator Feinstein had the  letter in hand, she never  brought up the charge during the public hearing, nor during her own meeting with the judge.
# original tokens: ['Even', 'though', 'Senator', 'Feinstein', 'had', 'the', 'letter', 'in', 'hand', ',', 'she', 'never', 'brought', 'up', 'the', 'charge', 'during', 'the', 'public', 'hearing', ',', 'nor', 'during', 'her', 'own', 'meeting', 'with', 'the', 'judge', '.']
# cleaned: ['Even', 'though', 'Senator', 'Feinstein', 'letter', 'hand', 'never', 'brought', 'charge', 'public', 'hearing', 'meeting', 'judge']
# string: One hundred thousand  persons were killed in  Fez on that occasion, and 120,000 in Marrakesh.
# original tokens: ['One', 'hundred', 'thousand', 'persons', 'were', 'killed', 'in', 'Fez', 'on', 'that', 'occasion', ',', 'and', '120,000', 'in', 'Marrakesh', '.']
# cleaned: ['One', 'hundred', 'thousand', 'persons', 'killed', 'Fez', 'occasion', 'Marrakesh']
# string: Ninety-two percent of individuals removed from the interior of the United States had previously been convicted of a criminal  offense.
# original tokens: ['Ninety-two', 'percent', 'of', 'individuals', 'removed', 'from', 'the', 'interior', 'of', 'the', 'United', 'States', 'had', 'previously', 'been', 'convicted', 'of', 'a', 'criminal', 'offense', '.']
# cleaned: ['percent', 'individuals', 'removed', 'interior', 'United', 'States', 'previously', 'convicted', 'criminal', 'offense']
# string:  Deep State DOJ tool  Rod Rosenstein refuses to comply with Trump’s executive order as afforded him by the US Constitution.
# original tokens: ['Deep', 'State', 'DOJ', 'tool', 'Rod', 'Rosenstein', 'refuses', 'to', 'comply', 'with', 'Trump', '’', 's', 'executive', 'order', 'as', 'afforded', 'him', 'by', 'the', 'US', 'Constitution', '.']
# cleaned: ['Deep', 'State', 'DOJ', 'tool', 'Rod', 'Rosenstein', 'refuses', 'comply', 'Trump', 'executive', 'order', 'afforded', 'US', 'Constitution']
# string:  Why?
# original tokens: ['Why', '?']
# cleaned: ['Why']
# string: As expected, at today’s hearing Kavanaugh will firmly  rebut the increasingly outrageous claims  being leveled at him.
# original tokens: ['As', 'expected', ',', 'at', 'today', '’', 's', 'hearing', 'Kavanaugh', 'will', 'firmly', 'rebut', 'the', 'increasingly', 'outrageous', 'claims', 'being', 'leveled', 'at', 'him', '.']
# cleaned: ['As', 'expected', 'today', 'hearing', 'Kavanaugh', 'firmly', 'rebut', 'increasingly', 'outrageous', 'claims', 'leveled']
# string:  His mere existence appears to have been fabricated by the very authorities who are cramming lies down our throats about this massacre for the sake of political agendas .
# original tokens: ['His', 'mere', 'existence', 'appears', 'to', 'have', 'been', 'fabricated', 'by', 'the', 'very', 'authorities', 'who', 'are', 'cramming', 'lies', 'down', 'our', 'throats', 'about', 'this', 'massacre', 'for', 'the', 'sake', 'of', 'political', 'agendas', '.']
# cleaned: ['His', 'mere', 'existence', 'appears', 'fabricated', 'authorities', 'cramming', 'lies', 'throats', 'massacre', 'sake', 'political', 'agendas']
# string: In an op-ed published several years ago by The Los Angeles Times, two members of Veteran Intelligence Professionals for Sanity, Coleen Rowley and Bogdan Dzakovic, pointed out that — If WikiLeaks had been up and running before 9/11 —  frustrated FBI investigators  might have chosen to leak information that their superiors bottled up, perhaps averting the terrorism attacks.
# original tokens: ['In', 'an', 'op-ed', 'published', 'several', 'years', 'ago', 'by', 'The', 'Los', 'Angeles', 'Times', ',', 'two', 'members', 'of', 'Veteran', 'Intelligence', 'Professionals', 'for', 'Sanity', ',', 'Coleen', 'Rowley', 'and', 'Bogdan', 'Dzakovic', ',', 'pointed', 'out', 'that', '—', 'If', 'WikiLeaks', 'had', 'been', 'up', 'and', 'running', 'before', '9/11', '—', 'frustrated', 'FBI', 'investigators', 'might', 'have', 'chosen', 'to', 'leak', 'information', 'that', 'their', 'superiors', 'bottled', 'up', ',', 'perhaps', 'averting', 'the', 'terrorism', 'attacks', '.']
# cleaned: ['In', 'published', 'several', 'years', 'ago', 'The', 'Los', 'Angeles', 'Times', 'two', 'members', 'Veteran', 'Intelligence', 'Professionals', 'Sanity', 'Coleen', 'Rowley', 'Bogdan', 'Dzakovic', 'pointed', 'If', 'WikiLeaks', 'running', 'frustrated', 'FBI', 'investigators', 'might', 'chosen', 'leak', 'information', 'superiors', 'bottled', 'perhaps', 'averting', 'terrorism', 'attacks']
# string: Simply expressing support for a terrorist organization or attack is  not against the  law.
# original tokens: ['Simply', 'expressing', 'support', 'for', 'a', 'terrorist', 'organization', 'or', 'attack', 'is', 'not', 'against', 'the', 'law', '.']
# cleaned: ['Simply', 'expressing', 'support', 'terrorist', 'organization', 'attack', 'law']
# string: This is clearly the testimony of an honest man who has only the good of the Church in his heart—a modern-day Athanasius  standing against something so much worse than Liberius .
# original tokens: ['This', 'is', 'clearly', 'the', 'testimony', 'of', 'an', 'honest', 'man', 'who', 'has', 'only', 'the', 'good', 'of', 'the', 'Church', 'in', 'his', 'heart—a', 'modern-day', 'Athanasius', 'standing', 'against', 'something', 'so', 'much', 'worse', 'than', 'Liberius', '.']
# cleaned: ['This', 'clearly', 'testimony', 'honest', 'man', 'good', 'Church', 'Athanasius', 'standing', 'something', 'much', 'worse', 'Liberius']
# string:  In Asia, preserving ‘face’ is essential.
# original tokens: ['In', 'Asia', ',', 'preserving', '‘', 'face', '’', 'is', 'essential', '.']
# cleaned: ['In', 'Asia', 'preserving', 'face', 'essential']
# string: But experts now warn that because they are being used so much to treat the infection,  antibiotics resistance is inevitable  and making this disease much more terrifying.
# original tokens: ['But', 'experts', 'now', 'warn', 'that', 'because', 'they', 'are', 'being', 'used', 'so', 'much', 'to', 'treat', 'the', 'infection', ',', 'antibiotics', 'resistance', 'is', 'inevitable', 'and', 'making', 'this', 'disease', 'much', 'more', 'terrifying', '.']
# cleaned: ['But', 'experts', 'warn', 'used', 'much', 'treat', 'infection', 'antibiotics', 'resistance', 'inevitable', 'making', 'disease', 'much', 'terrifying']
# string: In addition to securing the Gulf, the 5th Fleet serves as a constant  reminder to the Iranians of  their impotence.
# original tokens: ['In', 'addition', 'to', 'securing', 'the', 'Gulf', ',', 'the', '5th', 'Fleet', 'serves', 'as', 'a', 'constant', 'reminder', 'to', 'the', 'Iranians', 'of', 'their', 'impotence', '.']
# cleaned: ['In', 'addition', 'securing', 'Gulf', 'Fleet', 'serves', 'constant', 'reminder', 'Iranians', 'impotence']
# string: * Dianne Feinstein  Maxine Waters Adam Schiff Chuck Schumer Kamala Harris Kirsten  Gillibrand Keith Ellison Cory Booker
# original tokens: ['*', 'Dianne', 'Feinstein', 'Maxine', 'Waters', 'Adam', 'Schiff', 'Chuck', 'Schumer', 'Kamala', 'Harris', 'Kirsten', 'Gillibrand', 'Keith', 'Ellison', 'Cory', 'Booker']
# cleaned: ['Dianne', 'Feinstein', 'Maxine', 'Waters', 'Adam', 'Schiff', 'Chuck', 'Schumer', 'Kamala', 'Harris', 'Kirsten', 'Gillibrand', 'Keith', 'Ellison', 'Cory', 'Booker']
# string: About the clip, on Facebook, Zakkout wrote above it, “Makes a lot of sense!” Of course, this is coming from someone [Zakkout] who regularly refers to Jews as “ monkeys and pigs ,” and in February 2016, circulated on social media a report claiming that “the Holocaust was faked.” The report calls the Holocaust “the biggest lie ever foisted upon humanity” and was produced by a media outlet which describes Hitler as “the greatest leader in modern Western history.”
# original tokens: ['About', 'the', 'clip', ',', 'on', 'Facebook', ',', 'Zakkout', 'wrote', 'above', 'it', ',', '“', 'Makes', 'a', 'lot', 'of', 'sense', '!', '”', 'Of', 'course', ',', 'this', 'is', 'coming', 'from', 'someone', '[', 'Zakkout', ']', 'who', 'regularly', 'refers', 'to', 'Jews', 'as', '“', 'monkeys', 'and', 'pigs', ',', '”', 'and', 'in', 'February', '2016', ',', 'circulated', 'on', 'social', 'media', 'a', 'report', 'claiming', 'that', '“', 'the', 'Holocaust', 'was', 'faked.', '”', 'The', 'report', 'calls', 'the', 'Holocaust', '“', 'the', 'biggest', 'lie', 'ever', 'foisted', 'upon', 'humanity', '”', 'and', 'was', 'produced', 'by', 'a', 'media', 'outlet', 'which', 'describes', 'Hitler', 'as', '“', 'the', 'greatest', 'leader', 'in', 'modern', 'Western', 'history', '.', '”']
# cleaned: ['About', 'clip', 'Facebook', 'Zakkout', 'wrote', 'Makes', 'lot', 'sense', 'Of', 'course', 'coming', 'someone', 'Zakkout', 'regularly', 'refers', 'Jews', 'monkeys', 'pigs', 'February', 'circulated', 'social', 'media', 'report', 'claiming', 'Holocaust', 'The', 'report', 'calls', 'Holocaust', 'biggest', 'lie', 'ever', 'foisted', 'upon', 'humanity', 'produced', 'media', 'outlet', 'describes', 'Hitler', 'greatest', 'leader', 'modern', 'Western', 'history']
# string: It’s also the case that the more negative information comes out, the more it appears that the  Trump and his White House staff failed to do their jobs  in vetting and managing Kavanaugh.
# original tokens: ['It', '’', 's', 'also', 'the', 'case', 'that', 'the', 'more', 'negative', 'information', 'comes', 'out', ',', 'the', 'more', 'it', 'appears', 'that', 'the', 'Trump', 'and', 'his', 'White', 'House', 'staff', 'failed', 'to', 'do', 'their', 'jobs', 'in', 'vetting', 'and', 'managing', 'Kavanaugh', '.']
# cleaned: ['It', 'also', 'case', 'negative', 'information', 'comes', 'appears', 'Trump', 'White', 'House', 'staff', 'failed', 'jobs', 'vetting', 'managing', 'Kavanaugh']
# string:  To eradicate these, Muslims are required to wage war until there exists none of it in the world, and the only religion is that of Allah .
# original tokens: ['To', 'eradicate', 'these', ',', 'Muslims', 'are', 'required', 'to', 'wage', 'war', 'until', 'there', 'exists', 'none', 'of', 'it', 'in', 'the', 'world', ',', 'and', 'the', 'only', 'religion', 'is', 'that', 'of', 'Allah', '.']
# cleaned: ['To', 'eradicate', 'Muslims', 'required', 'wage', 'war', 'exists', 'none', 'world', 'religion', 'Allah']
# string: Unlike McFarland, Habib  Powell had  no national security background.
# original tokens: ['Unlike', 'McFarland', ',', 'Habib', 'Powell', 'had', 'no', 'national', 'security', 'background', '.']
# cleaned: ['Unlike', 'McFarland', 'Habib', 'Powell', 'national', 'security', 'background']
# string: Will Brett Kavanaugh be confirmed to the Supreme  Court?
# original tokens: ['Will', 'Brett', 'Kavanaugh', 'be', 'confirmed', 'to', 'the', 'Supreme', 'Court', '?']
# cleaned: ['Will', 'Brett', 'Kavanaugh', 'confirmed', 'Supreme', 'Court']
# string:  This is a matter of life and death, and any complacency towards Islam is treasonous. We do not wish the West to continue with Islamization, nor that your actions contribute to it .
# original tokens: ['This', 'is', 'a', 'matter', 'of', 'life', 'and', 'death', ',', 'and', 'any', 'complacency', 'towards', 'Islam', 'is', 'treasonous', '.', 'We', 'do', 'not', 'wish', 'the', 'West', 'to', 'continue', 'with', 'Islamization', ',', 'nor', 'that', 'your', 'actions', 'contribute', 'to', 'it', '.']
# cleaned: ['This', 'matter', 'life', 'death', 'complacency', 'towards', 'Islam', 'treasonous', 'We', 'wish', 'West', 'continue', 'Islamization', 'actions', 'contribute']
# string: We have previously shown that the Guardian even uses  fascist propaganda tropes  to smear the Russian people.
# original tokens: ['We', 'have', 'previously', 'shown', 'that', 'the', 'Guardian', 'even', 'uses', 'fascist', 'propaganda', 'tropes', 'to', 'smear', 'the', 'Russian', 'people', '.']
# cleaned: ['We', 'previously', 'shown', 'Guardian', 'even', 'uses', 'fascist', 'propaganda', 'tropes', 'smear', 'Russian', 'people']
# string:  Unless and until we take seriously our call to sanctity, we, as an institution and as individuals, will continue to suffer the “wages of sin .”
# original tokens: ['Unless', 'and', 'until', 'we', 'take', 'seriously', 'our', 'call', 'to', 'sanctity', ',', 'we', ',', 'as', 'an', 'institution', 'and', 'as', 'individuals', ',', 'will', 'continue', 'to', 'suffer', 'the', '“', 'wages', 'of', 'sin', '.', '”']
# cleaned: ['Unless', 'take', 'seriously', 'call', 'sanctity', 'institution', 'individuals', 'continue', 'suffer', 'wages', 'sin']
# string:  If one considers and weighs this matter, one knows: one may not bless a union of two homosexual men or of lesbian women .
# original tokens: ['If', 'one', 'considers', 'and', 'weighs', 'this', 'matter', ',', 'one', 'knows', ':', 'one', 'may', 'not', 'bless', 'a', 'union', 'of', 'two', 'homosexual', 'men', 'or', 'of', 'lesbian', 'women', '.']
# cleaned: ['If', 'one', 'considers', 'weighs', 'matter', 'one', 'knows', 'one', 'may', 'bless', 'union', 'two', 'homosexual', 'men', 'lesbian', 'women']
# string:  I don’t know what it will take  to exorcise the “spirit of Vatican II” – the spirit of aggiornamento – from the Church.
# original tokens: ['I', 'don', '’', 't', 'know', 'what', 'it', 'will', 'take', 'to', 'exorcise', 'the', '“', 'spirit', 'of', 'Vatican', 'II', '”', '–', 'the', 'spirit', 'of', 'aggiornamento', '–', 'from', 'the', 'Church', '.']
# cleaned: ['know', 'take', 'exorcise', 'spirit', 'Vatican', 'II', 'spirit', 'aggiornamento', 'Church']
# string: President Trump quoted the  nation’s most prominent conservative radio host as he urged GOP  senators to get onboard Tuesday:
# original tokens: ['President', 'Trump', 'quoted', 'the', 'nation', '’', 's', 'most', 'prominent', 'conservative', 'radio', 'host', 'as', 'he', 'urged', 'GOP', 'senators', 'to', 'get', 'onboard', 'Tuesday', ':']
# cleaned: ['President', 'Trump', 'quoted', 'nation', 'prominent', 'conservative', 'radio', 'host', 'urged', 'GOP', 'senators', 'get', 'onboard', 'Tuesday']
# string: But one goal behind  report's release, according to an official familiar with its contents, is to make clear that the US is not likely to be open to exemptions of  any kind.
# original tokens: ['But', 'one', 'goal', 'behind', 'report', "'s", 'release', ',', 'according', 'to', 'an', 'official', 'familiar', 'with', 'its', 'contents', ',', 'is', 'to', 'make', 'clear', 'that', 'the', 'US', 'is', 'not', 'likely', 'to', 'be', 'open', 'to', 'exemptions', 'of', 'any', 'kind', '.']
# cleaned: ['But', 'one', 'goal', 'behind', 'report', 'release', 'according', 'official', 'familiar', 'contents', 'make', 'clear', 'US', 'likely', 'open', 'exemptions', 'kind']
# string:  Trump is in the driver’s seat because the CIA cannot afford to permit the American people to see the records it wants to continue to be kept secret .
# original tokens: ['Trump', 'is', 'in', 'the', 'driver', '’', 's', 'seat', 'because', 'the', 'CIA', 'can', 'not', 'afford', 'to', 'permit', 'the', 'American', 'people', 'to', 'see', 'the', 'records', 'it', 'wants', 'to', 'continue', 'to', 'be', 'kept', 'secret', '.']
# cleaned: ['Trump', 'driver', 'seat', 'CIA', 'afford', 'permit', 'American', 'people', 'see', 'records', 'wants', 'continue', 'kept', 'secret']
# string: These are willing  to live in the freest country in the world  as long as it is not them that have to sacrifice to maintain it.
# original tokens: ['These', 'are', 'willing', 'to', 'live', 'in', 'the', 'freest', 'country', 'in', 'the', 'world', 'as', 'long', 'as', 'it', 'is', 'not', 'them', 'that', 'have', 'to', 'sacrifice', 'to', 'maintain', 'it', '.']
# cleaned: ['These', 'willing', 'live', 'freest', 'country', 'world', 'long', 'sacrifice', 'maintain']
# string: “ I didn’t agree with their ideology,” Khweis said in an interview with Kurdistan24 in 2016. “Our daily life was basically prayer, eating, and learning about the religion for about eight hours .” Kweis graduated from Alexandria’s Thomas Edison High School in 2007, where friends described him as “one of the guys.” “He wasn’t someone who was an outcast or something like that — he was one of the guys,” Harrison Weinhold told CBS News in March 2016.
# original tokens: ['“', 'I', 'didn', '’', 't', 'agree', 'with', 'their', 'ideology', ',', '”', 'Khweis', 'said', 'in', 'an', 'interview', 'with', 'Kurdistan24', 'in', '2016', '.', '“', 'Our', 'daily', 'life', 'was', 'basically', 'prayer', ',', 'eating', ',', 'and', 'learning', 'about', 'the', 'religion', 'for', 'about', 'eight', 'hours', '.', '”', 'Kweis', 'graduated', 'from', 'Alexandria', '’', 's', 'Thomas', 'Edison', 'High', 'School', 'in', '2007', ',', 'where', 'friends', 'described', 'him', 'as', '“', 'one', 'of', 'the', 'guys.', '”', '“', 'He', 'wasn', '’', 't', 'someone', 'who', 'was', 'an', 'outcast', 'or', 'something', 'like', 'that', '—', 'he', 'was', 'one', 'of', 'the', 'guys', ',', '”', 'Harrison', 'Weinhold', 'told', 'CBS', 'News', 'in', 'March', '2016', '.']
# ...
# cleaned: ['Wasserman', 'Schultz', 'brother', 'prosecutor', 'office', 'handling', 'case', 'tweeted']
# string: This article is featured in the  new Print/E-edition of  The Remnant.
# original tokens: ['This', 'article', 'is', 'featured', 'in', 'the', 'new', 'Print/E-edition', 'of', 'The', 'Remnant', '.']
# cleaned: ['This', 'article', 'featured', 'new', 'The', 'Remnant']
# string:  Proving a negative is nearly impossible .
# original tokens: ['Proving', 'a', 'negative', 'is', 'nearly', 'impossible', '.']
# cleaned: ['Proving', 'negative', 'nearly', 'impossible']
# string:  The Guardian did not make a mistake in vilifying Assange without a shred of evidence. It did what it is designed to do .
# original tokens: ['The', 'Guardian', 'did', 'not', 'make', 'a', 'mistake', 'in', 'vilifying', 'Assange', 'without', 'a', 'shred', 'of', 'evidence', '.', 'It', 'did', 'what', 'it', 'is', 'designed', 'to', 'do', '.']
# cleaned: ['The', 'Guardian', 'make', 'mistake', 'vilifying', 'Assange', 'without', 'shred', 'evidence', 'It', 'designed']
# string: She did say, however, that she favors a one-state, not two-state, “solution” to the Israeli-Palestinian conflict:  “One state.
# original tokens: ['She', 'did', 'say', ',', 'however', ',', 'that', 'she', 'favors', 'a', 'one-state', ',', 'not', 'two-state', ',', '“', 'solution', '”', 'to', 'the', 'Israeli-Palestinian', 'conflict', ':', '“', 'One', 'state', '.']
# cleaned: ['She', 'say', 'however', 'favors', 'solution', 'conflict', 'One', 'state']
# string:  The Trump administration  has levied tough sanctions on Russia.
# original tokens: ['The', 'Trump', 'administration', 'has', 'levied', 'tough', 'sanctions', 'on', 'Russia', '.']
# cleaned: ['The', 'Trump', 'administration', 'levied', 'tough', 'sanctions', 'Russia']
# string: To see what US intervention—through military support and the support of opposition groups—does to countries, one need only look at Syria, Iraq, Afghanistan, and Libya to see the horrific death tolls and  war-ravaged dystopias  left in America’s wake.
# original tokens: ['To', 'see', 'what', 'US', 'intervention—through', 'military', 'support', 'and', 'the', 'support', 'of', 'opposition', 'groups—does', 'to', 'countries', ',', 'one', 'need', 'only', 'look', 'at', 'Syria', ',', 'Iraq', ',', 'Afghanistan', ',', 'and', 'Libya', 'to', 'see', 'the', 'horrific', 'death', 'tolls', 'and', 'war-ravaged', 'dystopias', 'left', 'in', 'America', '’', 's', 'wake', '.']
# cleaned: ['To', 'see', 'US', 'military', 'support', 'support', 'opposition', 'countries', 'one', 'need', 'look', 'Syria', 'Iraq', 'Afghanistan', 'Libya', 'see', 'horrific', 'death', 'tolls', 'dystopias', 'left', 'America', 'wake']
# string: Still,  about  one-third of Puerto Rico is without power.
# original tokens: ['Still', ',', 'about', 'one-third', 'of', 'Puerto', 'Rico', 'is', 'without', 'power', '.']
# cleaned: ['Still', 'Puerto', 'Rico', 'without', 'power']
# string: “ I have no doubt from the information circulated about me and campaign run against me prior to this vote that this was about my Jewish identity, and nothing more ,” wrote Lew.
# original tokens: ['“', 'I', 'have', 'no', 'doubt', 'from', 'the', 'information', 'circulated', 'about', 'me', 'and', 'campaign', 'run', 'against', 'me', 'prior', 'to', 'this', 'vote', 'that', 'this', 'was', 'about', 'my', 'Jewish', 'identity', ',', 'and', 'nothing', 'more', ',', '”', 'wrote', 'Lew', '.']
# cleaned: ['doubt', 'information', 'circulated', 'campaign', 'run', 'prior', 'vote', 'Jewish', 'identity', 'nothing', 'wrote', 'Lew']
# string: I'm not  sure if he  should have.
# original tokens: ['I', "'m", 'not', 'sure', 'if', 'he', 'should', 'have', '.']
# cleaned: ['sure']
# string: We planned to bring  the Stars and Stripes, as well as British and Danish flags, and participate in Armed Forces Day memorial commemorations at the Royal Artillery Barracks in Woolwich, where Rigby served.
# original tokens: ['We', 'planned', 'to', 'bring', 'the', 'Stars', 'and', 'Stripes', ',', 'as', 'well', 'as', 'British', 'and', 'Danish', 'flags', ',', 'and', 'participate', 'in', 'Armed', 'Forces', 'Day', 'memorial', 'commemorations', 'at', 'the', 'Royal', 'Artillery', 'Barracks', 'in', 'Woolwich', ',', 'where', 'Rigby', 'served', '.']
# cleaned: ['We', 'planned', 'bring', 'Stars', 'Stripes', 'well', 'British', 'Danish', 'flags', 'participate', 'Armed', 'Forces', 'Day', 'memorial', 'commemorations', 'Royal', 'Artillery', 'Barracks', 'Woolwich', 'Rigby', 'served']
# string: If it did, it might not be so deferential to the deal that Trump and the CIA are about to make to continue the JFK assassination cover-up by continuing  to keep some of the CIA’s decades-old JFK’s related assassination records secret from the American people .
# original tokens: ['If', 'it', 'did', ',', 'it', 'might', 'not', 'be', 'so', 'deferential', 'to', 'the', 'deal', 'that', 'Trump', 'and', 'the', 'CIA', 'are', 'about', 'to', 'make', 'to', 'continue', 'the', 'JFK', 'assassination', 'cover-up', 'by', 'continuing', 'to', 'keep', 'some', 'of', 'the', 'CIA', '’', 's', 'decades-old', 'JFK', '’', 's', 'related', 'assassination', 'records', 'secret', 'from', 'the', 'American', 'people', '.']
# cleaned: ['If', 'might', 'deferential', 'deal', 'Trump', 'CIA', 'make', 'continue', 'JFK', 'assassination', 'continuing', 'keep', 'CIA', 'JFK', 'related', 'assassination', 'records', 'secret', 'American', 'people']
# string: Democrats may be overestimating the strength  of their  hand.
# original tokens: ['Democrats', 'may', 'be', 'overestimating', 'the', 'strength', 'of', 'their', 'hand', '.']
# cleaned: ['Democrats', 'may', 'overestimating', 'strength', 'hand']
# string: This new report documenting yet another instance of a possible second shooter comes on the  heels of dozens of similar reports, with the most recent arriving in the form of air traffic  control audio that directly stated that there were active shooters on the runway.
# original tokens: ['This', 'new', 'report', 'documenting', 'yet', 'another', 'instance', 'of', 'a', 'possible', 'second', 'shooter', 'comes', 'on', 'the', 'heels', 'of', 'dozens', 'of', 'similar', 'reports', ',', 'with', 'the', 'most', 'recent', 'arriving', 'in', 'the', 'form', 'of', 'air', 'traffic', 'control', 'audio', 'that', 'directly', 'stated', 'that', 'there', 'were', 'active', 'shooters', 'on', 'the', 'runway', '.']
# cleaned: ['This', 'new', 'report', 'documenting', 'yet', 'another', 'instance', 'possible', 'second', 'shooter', 'comes', 'heels', 'dozens', 'similar', 'reports', 'recent', 'arriving', 'form', 'air', 'traffic', 'control', 'audio', 'directly', 'stated', 'active', 'shooters', 'runway']
# string: Certainly, some of the facts that I was to reveal were covered by the pontifical secret that I had promised to observe and that I had faithfully observed from the beginning of my service to the  Holy See.
# original tokens: ['Certainly', ',', 'some', 'of', 'the', 'facts', 'that', 'I', 'was', 'to', 'reveal', 'were', 'covered', 'by', 'the', 'pontifical', 'secret', 'that', 'I', 'had', 'promised', 'to', 'observe', 'and', 'that', 'I', 'had', 'faithfully', 'observed', 'from', 'the', 'beginning', 'of', 'my', 'service', 'to', 'the', 'Holy', 'See', '.']
# cleaned: ['Certainly', 'facts', 'reveal', 'covered', 'pontifical', 'secret', 'promised', 'observe', 'faithfully', 'observed', 'beginning', 'service', 'Holy', 'See']
# string:  This spring, Bible classes such as Trenton’s are  on the minds of many here in Mercer County.
# original tokens: ['This', 'spring', ',', 'Bible', 'classes', 'such', 'as', 'Trenton', '’', 's', 'are', 'on', 'the', 'minds', 'of', 'many', 'here', 'in', 'Mercer', 'County', '.']
# cleaned: ['This', 'spring', 'Bible', 'classes', 'Trenton', 'minds', 'many', 'Mercer', 'County']
# string: I never thought I’d see the day when a preening, Internet-created neo-Catholic doyenne such as Simcha Fisher, as notorious as Mark Shea for her crude and often unprintable invective against traditionalists, would  unload on Pope Bergoglio  with the following headline: “Does Francis know he sounds like an abuser?”
# original tokens: ['I', 'never', 'thought', 'I', '’', 'd', 'see', 'the', 'day', 'when', 'a', 'preening', ',', 'Internet-created', 'neo-Catholic', 'doyenne', 'such', 'as', 'Simcha', 'Fisher', ',', 'as', 'notorious', 'as', 'Mark', 'Shea', 'for', 'her', 'crude', 'and', 'often', 'unprintable', 'invective', 'against', 'traditionalists', ',', 'would', 'unload', 'on', 'Pope', 'Bergoglio', 'with', 'the', 'following', 'headline', ':', '“', 'Does', 'Francis', 'know', 'he', 'sounds', 'like', 'an', 'abuser', '?', '”']
# cleaned: ['never', 'thought', 'see', 'day', 'preening', 'doyenne', 'Simcha', 'Fisher', 'notorious', 'Mark', 'Shea', 'crude', 'often', 'unprintable', 'invective', 'traditionalists', 'would', 'unload', 'Pope', 'Bergoglio', 'following', 'headline', 'Does', 'Francis', 'know', 'sounds', 'like', 'abuser']
# string:  How many more victims went ignored by investigators?
# original tokens: ['How', 'many', 'more', 'victims', 'went', 'ignored', 'by', 'investigators', '?']
# cleaned: ['How', 'many', 'victims', 'went', 'ignored', 'investigators']
# string: In January 2017, in the days around his father’s death, Abid removed Gilani as the beneficiary of his father’s life insurance and replaced her with himself, which  led to a lawsuit, TheDCNF previously reported.
# original tokens: ['In', 'January', '2017', ',', 'in', 'the', 'days', 'around', 'his', 'father', '’', 's', 'death', ',', 'Abid', 'removed', 'Gilani', 'as', 'the', 'beneficiary', 'of', 'his', 'father', '’', 's', 'life', 'insurance', 'and', 'replaced', 'her', 'with', 'himself', ',', 'which', 'led', 'to', 'a', 'lawsuit', ',', 'TheDCNF', 'previously', 'reported', '.']
# cleaned: ['In', 'January', 'days', 'around', 'father', 'death', 'Abid', 'removed', 'Gilani', 'beneficiary', 'father', 'life', 'insurance', 'replaced', 'led', 'lawsuit', 'TheDCNF', 'previously', 'reported']
# string:  Is the principal acting on this?
# original tokens: ['Is', 'the', 'principal', 'acting', 'on', 'this', '?']
# cleaned: ['Is', 'principal', 'acting']
# string: March 5th,  2017.
# original tokens: ['March', '5th', ',', '2017', '.']
# cleaned: ['March']
# string: The  exhibition closes with Fishback’s anti-Israel agenda.
# original tokens: ['The', 'exhibition', 'closes', 'with', 'Fishback', '’', 's', 'anti-Israel', 'agenda', '.']
# cleaned: ['The', 'exhibition', 'closes', 'Fishback', 'agenda']
# string: “You don’t have to push  religion with it.
# original tokens: ['“', 'You', 'don', '’', 't', 'have', 'to', 'push', 'religion', 'with', 'it', '.']
# cleaned: ['You', 'push', 'religion']
# string: For example, a Minnesota public school is  forcing  Kindergarten students to study ‘white privilege’.
# original tokens: ['For', 'example', ',', 'a', 'Minnesota', 'public', 'school', 'is', 'forcing', 'Kindergarten', 'students', 'to', 'study', '‘', 'white', 'privilege', '’', '.']
# cleaned: ['For', 'example', 'Minnesota', 'public', 'school', 'forcing', 'Kindergarten', 'students', 'study', 'white', 'privilege']
# string: As a result, 58,177  Americans  would lose their lives.
# original tokens: ['As', 'a', 'result', ',', '58,177', 'Americans', 'would', 'lose', 'their', 'lives', '.']
# cleaned: ['As', 'result', 'Americans', 'would', 'lose', 'lives']
# string: But for Carmelite  nuns, Sister said, these  ideas are the antithesis of the intentions of St. Teresa.
# original tokens: ['But', 'for', 'Carmelite', 'nuns', ',', 'Sister', 'said', ',', 'these', 'ideas', 'are', 'the', 'antithesis', 'of', 'the', 'intentions', 'of', 'St.', 'Teresa', '.']
# cleaned: ['But', 'Carmelite', 'nuns', 'Sister', 'said', 'ideas', 'antithesis', 'intentions', 'Teresa']
# string:  But if you are a freedom-loving American  who values your liberties and the God-given right to defend them, happy is NOT what you should be feeling right now.
# original tokens: ['But', 'if', 'you', 'are', 'a', 'freedom-loving', 'American', 'who', 'values', 'your', 'liberties', 'and', 'the', 'God-given', 'right', 'to', 'defend', 'them', ',', 'happy', 'is', 'NOT', 'what', 'you', 'should', 'be', 'feeling', 'right', 'now', '.']
# cleaned: ['But', 'American', 'values', 'liberties', 'right', 'defend', 'happy', 'NOT', 'feeling', 'right']
# string: I heard lots of  gut-wrenching stories  in my two-and-a-half years there, but none of them involved Archbishop McCarrick.
# original tokens: ['I', 'heard', 'lots', 'of', 'gut-wrenching', 'stories', 'in', 'my', 'two-and-a-half', 'years', 'there', ',', 'but', 'none', 'of', 'them', 'involved', 'Archbishop', 'McCarrick', '.']
# cleaned: ['heard', 'lots', 'stories', 'years', 'none', 'involved', 'Archbishop', 'McCarrick']
# string:  Los Angeles Times
# original tokens: ['Los', 'Angeles', 'Times']
# cleaned: ['Los', 'Angeles', 'Times']
# string: “You cannot obstruct justice by openly exercising  your First Amendment rights and openly criticizing a prosecution,  whether you’re right or wrong,” he said.
# original tokens: ['“', 'You', 'can', 'not', 'obstruct', 'justice', 'by', 'openly', 'exercising', 'your', 'First', 'Amendment', 'rights', 'and', 'openly', 'criticizing', 'a', 'prosecution', ',', 'whether', 'you', '’', 're', 'right', 'or', 'wrong', ',', '”', 'he', 'said', '.']
# cleaned: ['You', 'obstruct', 'justice', 'openly', 'exercising', 'First', 'Amendment', 'rights', 'openly', 'criticizing', 'prosecution', 'whether', 'right', 'wrong', 'said']
# string: NewsCatholic Church,  Family, Marriage
# original tokens: ['NewsCatholic', 'Church', ',', 'Family', ',', 'Marriage']
# cleaned: ['NewsCatholic', 'Church', 'Family', 'Marriage']
# string: Remember our saying, modern day fairy  tales start with ‘once I am  elected.
# original tokens: ['Remember', 'our', 'saying', ',', 'modern', 'day', 'fairy', 'tales', 'start', 'with', '‘', 'once', 'I', 'am', 'elected', '.']
# cleaned: ['Remember', 'saying', 'modern', 'day', 'fairy', 'tales', 'start', 'elected']
# string: Why  not  open up to Iran with massive amounts of trade and other contacts?
# original tokens: ['Why', 'not', 'open', 'up', 'to', 'Iran', 'with', 'massive', 'amounts', 'of', 'trade', 'and', 'other', 'contacts', '?']
# cleaned: ['Why', 'open', 'Iran', 'massive', 'amounts', 'trade', 'contacts']
# string:  He also sang an Islamic State fight song and recalled making a replica of the group’s flag. He said he wanted to replace his neighbor’s American flag with it .
# original tokens: ['He', 'also', 'sang', 'an', 'Islamic', 'State', 'fight', 'song', 'and', 'recalled', 'making', 'a', 'replica', 'of', 'the', 'group', '’', 's', 'flag', '.', 'He', 'said', 'he', 'wanted', 'to', 'replace', 'his', 'neighbor', '’', 's', 'American', 'flag', 'with', 'it', '.']
# cleaned: ['He', 'also', 'sang', 'Islamic', 'State', 'fight', 'song', 'recalled', 'making', 'replica', 'group', 'flag', 'He', 'said', 'wanted', 'replace', 'neighbor', 'American', 'flag']
# string: We hear again, as we did incessantly from the Kasperians at the Synods, about the hard case of the poor, poor woman who has been abandoned by the first husband, and who “finds no other way out than to entrust oneself to a kind-hearted person,” …  with whom, I guess, she has also no choice but to have sexual relations. Because of kind-heartedness .
# original tokens: ['We', 'hear', 'again', ',', 'as', 'we', 'did', 'incessantly', 'from', 'the', 'Kasperians', 'at', 'the', 'Synods', ',', 'about', 'the', 'hard', 'case', 'of', 'the', 'poor', ',', 'poor', 'woman', 'who', 'has', 'been', 'abandoned', 'by', 'the', 'first', 'husband', ',', 'and', 'who', '“', 'finds', 'no', 'other', 'way', 'out', 'than', 'to', 'entrust', 'oneself', 'to', 'a', 'kind-hearted', 'person', ',', '”', '…', 'with', 'whom', ',', 'I', 'guess', ',', 'she', 'has', 'also', 'no', 'choice', 'but', 'to', 'have', 'sexual', 'relations', '.', 'Because', 'of', 'kind-heartedness', '.']
# cleaned: ['We', 'hear', 'incessantly', 'Kasperians', 'Synods', 'hard', 'case', 'poor', 'poor', 'woman', 'abandoned', 'first', 'husband', 'finds', 'way', 'entrust', 'oneself', 'person', 'guess', 'also', 'choice', 'sexual', 'relations', 'Because']
