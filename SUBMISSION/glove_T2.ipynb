# %%
import os
import pandas as pd 
from gensim.models import KeyedVectors
import matplotlib.pyplot as plt
import nltk
from nltk import word_tokenize as tokenize
from nltk.corpus import stopwords as stopwords
from nltk.stem import PorterStemmer, SnowballStemmer
import torch
from torch.utils.data import DataLoader, Dataset
import numpy as np
from torch import nn
from tqdm import tqdm
import uuid
import re
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import json

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/rfd/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/rfd/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/rfd/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
try :
  from google.colab import drive
  IN_COLAB = True
except:
  IN_COLAB = False
print('IN COLAB: ', IN_COLAB)


parentdir = "./propaganda_dataset_v2"
train_file= "propaganda_train.tsv"
val_file= "propaganda_val.tsv"

train_path=os.path.join(parentdir,train_file)
val_path=os.path.join(parentdir,val_file)

if IN_COLAB:
  train_path = '/content/propaganda_train.tsv'
  val_path = '/content/propaganda_val.tsv'

train_df=pd.read_csv(train_path,delimiter="\t",quotechar='|')
val_df=pd.read_csv(val_path,delimiter="\t",quotechar='|')
train_df = train_df.drop(train_df[train_df['label'] == 'not_propaganda'].index)
val_df = val_df.drop(val_df[val_df['label'] == 'not_propaganda'].index)
train_df
val_df
# Out:
# IN COLAB:  False
#                          label  \
# 1    causal_oversimplification
# 2     appeal_to_fear_prejudice
# 4                   repetition
# 5        name_calling,labeling
# 6              loaded_language
# ..                         ...
# 629                flag_waving
# 631                flag_waving
# 632            loaded_language
# 638                flag_waving
# 639  causal_oversimplification
#
#                                      tagged_in_context
# 1    Mostly because <BOS> the country would not las...
# 2    Lyndon Johnson <BOS> gets Earl Warren and Sen....
# 4    It must be exacted from him directly in order ...
# 5    Is it any wonder that priests and laity alike ...
# 6    Health workers have been asked to work with co...
# ..                                                 ...
# 629  As a result, 58,177 <BOS> Americans <EOS> woul...
# 631  <BOS> But if you are a freedom-loving American...
# 632  I heard lots of <BOS> gut-wrenching stories <E...
# 638  <BOS> He also sang an Islamic State fight song...
# 639  We hear again, as we did incessantly from the ...
#
# [309 rows x 2 columns]

# %%
import re
experiment = True

def extract_tagged_section(row):
    pattern = r'<BOS>.*?<EOS>'
    match = re.search(pattern, row['tagged_in_context'])
    return match.group() if match else ""

def extract_text_inside_tags(row):
    pattern = r'<BOS>(.*?)<EOS>'
    match = re.search(pattern, row['tagged_in_context'])
    return match.group(1).strip() if match else ""

def transform_multi_label(row):
    new_value = label_to_id[row['label']]
    return new_value

def transform_strip_tag(row):
    sent = row['tagged_in_context']
    cleaned_string = sent.replace("<BOS>", "")
    cleaned_string = cleaned_string.replace("<EOS>", "")
    return cleaned_string



label_to_id = {'flag_waving': 0, 'exaggeration,minimisation': 1, 'causal_oversimplification': 2, 'name_calling,labeling': 3, 'repetition': 4, 'doubt': 5, 'loaded_language': 6, 'appeal_to_fear_prejudice': 7}
id_to_label = {0: 'flag_waving', 1: 'exaggeration,minimisation', 2: 'causal_oversimplification', 3: 'name_calling,labeling', 4: 'repetition', 5: 'doubt',6: 'loaded_language', 7: 'appeal_to_fear_prejudice'}

train_df['label_str'] = train_df.apply(transform_multi_label, axis=1)
train_df['extract_no_tags'] = train_df.apply(extract_text_inside_tags, axis=1)
train_df['extract_with_tags'] = train_df.apply(extract_tagged_section, axis=1)

val_df['label_str'] = val_df.apply(transform_multi_label, axis=1)
val_df['extract_no_tags'] = val_df.apply(extract_text_inside_tags, axis=1)
val_df['extract_with_tags'] = val_df.apply(extract_tagged_section, axis=1)

val_df
# Out:
#                          label  \
# 1    causal_oversimplification
# 2     appeal_to_fear_prejudice
# 4                   repetition
# 5        name_calling,labeling
# 6              loaded_language
# ..                         ...
# 629                flag_waving
# 631                flag_waving
# 632            loaded_language
# 638                flag_waving
# 639  causal_oversimplification
#
#                                      tagged_in_context  label_str  \
# 1    Mostly because <BOS> the country would not las...          2
# 2    Lyndon Johnson <BOS> gets Earl Warren and Sen....          7
# 4    It must be exacted from him directly in order ...          4
# 5    Is it any wonder that priests and laity alike ...          3
# 6    Health workers have been asked to work with co...          6
# ..                                                 ...        ...
# 629  As a result, 58,177 <BOS> Americans <EOS> woul...          0
# 631  <BOS> But if you are a freedom-loving American...          0
# 632  I heard lots of <BOS> gut-wrenching stories <E...          6
# 638  <BOS> He also sang an Islamic State fight song...          0
# 639  We hear again, as we did incessantly from the ...          2
#
#                                        extract_no_tags  \
# 1    the country would not last long without an out...
# 2    gets Earl Warren and Sen. Richard Russel to jo...
# 4                                             infidels
# 5                                   the "gay lifestyle
# 6                              devastating communities
# ..                                                 ...
# 629                                          Americans
# 631           But if you are a freedom-loving American
# 632                              gut-wrenching stories
# 638  He also sang an Islamic State fight song and r...
# 639  with whom, I guess, she has also no choice but...
#
#                                      extract_with_tags
# 1    <BOS> the country would not last long without ...
# 2    <BOS> gets Earl Warren and Sen. Richard Russel...
# 4                                 <BOS> infidels <EOS>
# 5                       <BOS> the "gay lifestyle <EOS>
# 6                  <BOS> devastating communities <EOS>
# ..                                                 ...
# 629                              <BOS> Americans <EOS>
# 631  <BOS> But if you are a freedom-loving American...
# 632                  <BOS> gut-wrenching stories <EOS>
# 638  <BOS> He also sang an Islamic State fight song...
# 639  <BOS> with whom, I guess, she has also no choi...
#
# [309 rows x 5 columns]

# %%
def load_glove_embeddings(file_path):
    embeddings = {}
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            values = line.split()
            word = values[0]
            vector = np.asarray(values[1:], dtype='float32')
            embeddings[word] = vector
    return embeddings

# Load GloVe embeddings
glove_file_path = './glove.6B/glove.6B.300d.txt'
glove_embeddings = load_glove_embeddings(glove_file_path)

# %%
def transform_tokens_to_glove_no_stems(string, embeddings, pool_type='mean', normalise=False, len=300):
  vectors = []
  stops = set(stopwords.words('english'))
  original_tokens = tokenize(string)
  cleaned_tokens = [ w for w in original_tokens if w.isalpha() and w not in stops]
  
  for token in cleaned_tokens:
      if token in embeddings:
          vector = embeddings[token]
          if normalise:
              vector = vector / np.linalg.norm(vector)
          vectors.append(vector)
          
  if not vectors:
      return np.zeros(len)
  if pool_type == 'mean':
      return np.mean(vectors, axis=0)
  elif pool_type == 'max':
      return np.max(vectors, axis=0)
  else:
      raise ValueError("Invalid pool_type. Choose either 'mean' or 'max'.")
  

def transform_tokens_to_glove_with_stems(string, embeddings, pool_type='mean', normalise=False):
    stops = set(stopwords.words('english'))
    porter_stemmer = PorterStemmer()
    snowball_stemmer = SnowballStemmer('english')
    vectors = []
    original_tokens = tokenize(string)
    cleaned_tokens = [w for w in original_tokens if len(w) > 1 and w.isalpha() and w not in stops]
    for token in cleaned_tokens:
        if token in embeddings:
            vector = embeddings[token]
            if normalise:
                vector = vector / np.linalg.norm(vector)
            vectors.append(vector)
        else:
            porter_stem = porter_stemmer.stem(token)
            snowball_stem = snowball_stemmer.stem(token)
            if porter_stem in embeddings:
                vector = embeddings[porter_stem]
                if normalise:
                    vector = vector / np.linalg.norm(vector)
                vectors.append(vector)
            elif snowball_stem in embeddings:
                vector = embeddings[snowball_stem]
                if normalise:
                    vector = vector / np.linalg.norm(vector)
                vectors.append(vector)
    if not vectors:
        return np.zeros(300)
    if pool_type == 'mean':
        return np.mean(vectors, axis=0)
    elif pool_type == 'max':
        return np.max(vectors, axis=0)
    else:
        raise ValueError("Invalid pool_type. Choose either 'mean' or 'max'.")


# Example usage
sentence = "This is an example sentence."
embedding = transform_tokens_to_glove_no_stems(sentence, glove_embeddings, pool_type='mean', normalise=False)
embedding = transform_tokens_to_glove_with_stems(sentence, glove_embeddings, pool_type='mean', normalise=False)
print(embedding)
# Out:
# [-3.34453344e-01 -2.35425994e-01 -2.70007998e-01 -2.53540009e-01
#  -6.54696524e-02 -1.35613337e-01  9.06866565e-02 -3.52143317e-01
#  -4.80129987e-01 -1.05178678e+00  2.03958675e-01 -1.21916495e-01
#  -3.39329988e-01 -1.17597662e-01  6.10233359e-02 -1.22426666e-01
#   2.01176003e-01  5.26266657e-02 -1.39533892e-01 -4.30886656e-01
#   4.72079962e-02 -1.74243331e-01  4.36844975e-02 -2.01134339e-01
#  -5.27216680e-02 -4.23466675e-02  2.24244654e-01 -2.24231318e-01
#   8.83833040e-03 -4.01423335e-01 -1.85234979e-01  1.86613321e-01
#  -7.39266574e-02  5.98043315e-02  1.16076671e-01 -1.99541643e-01
#  -2.58783311e-01 -3.85793328e-01 -1.06729992e-01  1.54140994e-01
#   5.03346324e-01 -9.55793336e-02 -3.10696661e-01  1.18880995e-01
#   1.28136622e-02 -8.34829733e-02 -2.29526553e-02  4.77993339e-01
#  -9.13500190e-02  2.91133318e-02 -2.66466677e-01  1.48003325e-01
#   3.52866650e-01  1.50899664e-01  1.85936674e-01  6.92460015e-02
#   5.67033254e-02 -2.74230003e-01  1.13710016e-02 -9.46133360e-02
#   4.25999999e-01  1.41406670e-01  2.61559993e-01 -5.36509991e-01
#  -4.19246674e-01 -3.25947315e-01 -3.53926659e-01 -1.52459994e-01
#   3.37100029e-01  3.23570639e-01 -2.31826663e-01 -3.54085684e-01
#  -1.60281673e-01 -9.59953293e-02  7.78653324e-02  2.67519981e-01
#   1.94921657e-01  3.36933322e-02 -1.36629818e-03 -9.66433063e-02
#  -6.31233379e-02 -1.16878636e-01  2.51831979e-01 -3.51546675e-01
#  -1.90260008e-01 -1.52676657e-01 -2.65147984e-01  4.43856686e-01
#   8.70783329e-02  3.37345988e-01 -7.02053368e-01 -8.44171718e-02
#  -1.85729995e-01 -2.14587331e-01  8.27266648e-02  1.54473335e-01
#  -8.73013362e-02 -1.67758003e-01  5.08573353e-01  9.97466668e-02
#   3.06980070e-02 -1.59487665e-01  7.99300075e-02  3.53428990e-01
#  -2.53562659e-01  5.63724637e-02  6.87400028e-02 -1.54565990e-01
#   1.56615987e-01 -2.82133315e-02 -6.13099933e-02 -2.74233315e-02
#  -3.20013352e-02  1.50815323e-01  3.66513342e-01  5.58909960e-02
#   2.09948674e-01  2.36946002e-01 -1.03076003e-01  3.11026663e-01
#  -8.67733300e-01 -2.09959999e-01  7.14466646e-02  2.27574334e-01
#  -1.36949688e-01  2.04100013e-02 -2.16005012e-01 -2.17203006e-01
#  -2.56539345e-01  5.64093292e-01  1.32035002e-01 -1.86510012e-01
#  -2.14255676e-01  2.67489672e-01  1.92879006e-01  2.13298202e-01
#   2.02786669e-01 -1.61019996e-01  4.38290000e-01 -2.17544004e-01
#   1.86379313e-01 -5.99900000e-02 -4.14603323e-01  2.17990682e-01]

# %%
class CustomPropagandaDataset_vanilla(Dataset):
    def __init__(self,df, glove_embeddings, stems=False, pool = 'mean'):
        self.stems = stems
        self.labels=torch.tensor([label for label in df['label_str']])
        
        if self.stems==True:
            self.texts=torch.tensor([transform_tokens_to_glove_with_stems(string, glove_embeddings, pool_type=pool, normalise=False) for string in df['extract_no_tags']])
        else:    
            self.texts=torch.tensor([transform_tokens_to_glove_no_stems(string, glove_embeddings, pool_type=pool, normalise=False) for string in df['extract_no_tags']])
        
    def classes(self):
        return self.labels
    
    def __len__(self):
        return len(self.labels)
    
    def __getitem__(self,idx):
        texts=self.texts[idx]
        y=self.labels[idx]
        return texts,y

# %%
class Custom_MLP(nn.Module):
    def __init__(self, dropout=0.5, num_classes=8):
        super().__init__()
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.linear_1 = nn.Linear(300, 128)
        self.bn1 = nn.BatchNorm1d(128)  
        self.linear_2 = nn.Linear(128, 128)
        self.bn2 = nn.BatchNorm1d(128)  
        self.linear_3 = nn.Linear(128, num_classes)

    def forward(self, inputs):
        x = self.linear_1(inputs)
        x = self.bn1(x)  
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear_2(x)
        x = self.bn2(x)  
        x = self.relu(x)
        x = self.dropout(x)
        x = self.linear_3(x)
        return x

device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cpu

# %%
epochs =150
n_classes = 8
bn = 100
lr = 5e-5
stem_v = False
pool_v = 'mean'
norm_v = False
dr = 0.5

for stem_v in [True, False]:
    train_data = CustomPropagandaDataset_vanilla(train_df, glove_embeddings, pool=pool_v, stems=stem_v)
    val_data = CustomPropagandaDataset_vanilla(val_df, glove_embeddings, pool=pool_v, stems=stem_v)
    
    train_dataloader=torch.utils.data.DataLoader(train_data,batch_size=bn,shuffle=True)
    val_dataloader=torch.utils.data.DataLoader(val_data,batch_size=bn)
    
    model=Custom_MLP(num_classes=n_classes, dropout = dr).to(device)
    criterion=nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(params=model.parameters(), lr=lr)

    train_acc_list = []
    train_loss_list = []
    val_acc_list = []
    val_loss_list = []

    best_val_acc = 0
    best_epoch = 0
    best_model_state = None

    model_id = str(uuid.uuid4())


    for epoch_num in range(epochs):

        total_acc_train=0
        total_loss_train=0
        model.train()

        for train_input,train_label in train_dataloader:

            train_input = train_input.to(device).float()
            train_label = train_label.to(device)
            output_1=model(train_input)

            batch_loss_1=criterion(output_1,train_label)

            total_loss_train += batch_loss_1.item()

            acc=(output_1.argmax(dim=1)==train_label).sum().item()
            total_acc_train+=acc

            model.zero_grad()
            batch_loss_1.backward()
            optimizer.step()

        total_acc_val=0
        total_loss_val=0

        y_true = []
        y_pred = []
        model.eval()
        with torch.no_grad():
            for val_input,val_label in val_dataloader:

                val_input = val_input.to(device).float()
                val_label = val_label.to(device)

                output_2=model(val_input)

                batch_loss_2=criterion(output_2,val_label)

                total_loss_val+=batch_loss_2.item()

                acc=(output_2.argmax(dim=1)==val_label).sum().item()
                total_acc_val+=acc

                # for scoring
                predicted = output_2.argmax(dim=1)
                y_true.extend(val_label.cpu().numpy())
                y_pred.extend(predicted.cpu().numpy())
        
        train_acc = total_acc_train / len(train_data)
        train_loss = total_loss_train / len(train_data)
        val_acc = total_acc_val / len(val_data)
        val_loss = total_loss_val / len(val_data)

        train_acc_list.append(train_acc)
        train_loss_list.append(train_loss)
        val_acc_list.append(val_acc)
        val_loss_list.append(val_loss)

        print(f'Epochs: {epoch_num+1} | Train Loss: {total_loss_train / len(train_data):.3f} | Train Accuracy: {total_acc_train/len(train_data):.3f}')
        print(f'Val loss: {total_loss_val/len(val_data):.3f} | Val Accuracy: {total_acc_val / len(val_data):.3f}')
        if val_acc > best_val_acc:
            best_epoch = epoch_num
            y_true_best = y_true.copy()
            y_pred_best = y_pred.copy()
            best_val_acc = val_acc
            best_model_state = model.state_dict()

        # if epoch_num == epochs-1:
        #     print(f'______{model_id}______')
        #     print(f'LR: {lr} FINAL ACC = {total_acc_val / len(val_data):.3f}')
        #     print(f'LR: {lr} BEST ACC = {best_val_acc:.3f}')
        #     print('____________')
            
    # Plot the accuracy and loss curves over epochs
    epochs_range = range(1, epochs+1)

    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, train_acc_list, label='Training Accuracy')
    plt.plot(epochs_range, val_acc_list, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(loc='lower right')
    plt.ylim(0, 1)  # Set y-axis limits from 0 to 1 for accuracy
    plt.title(f'Accuracy for lr {lr}, batch size {bn}, best ac: {best_val_acc:.2f}')

    # plt.subplot(1, 2, 2)
    # plt.plot(epochs_range, train_loss_list, label='Training Loss')
    # plt.plot(epochs_range, val_loss_list, label='Validation Loss')
    # plt.xlabel('Epochs')
    # plt.ylabel('Loss')
    # plt.legend(loc='upper right')
    # plt.title('Loss Curves')

    plt.tight_layout()
    plt.show()


    # analysis of best performing model
    classes = list(id_to_label.values())
    cm = confusion_matrix(y_true_best, y_pred_best)
    disp = ConfusionMatrixDisplay(cm)
    disp.plot()

    # Compute precision, recall, F1-score, and other metrics for the best model
    report = classification_report(y_true_best, y_pred_best, target_names=classes)
    print('Classification Report:')
    print(report)

    results_dict = {
        'model_id': model_id,
        'train_accuracy': train_acc_list,
        'train_loss': train_loss_list,
        'val_accuracy': val_acc_list,
        'val_loss': val_loss_list,
        'hyperparameters': {
            'learning_rate': lr,
            'num_epochs': epochs,
            'batch_size': bn,
            'stem_v':stem_v,
            'pool_v':pool_v,
            'norm_v':norm_v,
            'dropout_rate': dr,
        },
        'results': {
            "classes": n_classes,
            "last_acc": val_acc_list[-1],
            'best_acc': best_val_acc,
            'best_acc_epoch': best_epoch,
            'confusion_matrix': cm.tolist(),
            'classification_report': report
        }
    }


    # Save the results dictionary as a JSON file with the model ID
    results_filename = f'./results/glove_multi/glove_multi_results_{model_id}.json'
    with open(results_filename, 'w') as f:
        json.dump(results_dict, f, indent=4)
# Out:
# Epochs: 1 | Train Loss: 0.022 | Train Accuracy: 0.137
# Val loss: 0.027 | Val Accuracy: 0.149
# Epochs: 2 | Train Loss: 0.022 | Train Accuracy: 0.147
# Val loss: 0.026 | Val Accuracy: 0.162
# Epochs: 3 | Train Loss: 0.022 | Train Accuracy: 0.153
# Val loss: 0.026 | Val Accuracy: 0.201
# Epochs: 4 | Train Loss: 0.021 | Train Accuracy: 0.149
# Val loss: 0.026 | Val Accuracy: 0.214
# Epochs: 5 | Train Loss: 0.021 | Train Accuracy: 0.164
# Val loss: 0.026 | Val Accuracy: 0.227
# Epochs: 6 | Train Loss: 0.021 | Train Accuracy: 0.167
# Val loss: 0.025 | Val Accuracy: 0.236
# Epochs: 7 | Train Loss: 0.021 | Train Accuracy: 0.170
# Val loss: 0.025 | Val Accuracy: 0.249
# Epochs: 8 | Train Loss: 0.021 | Train Accuracy: 0.190
# Val loss: 0.025 | Val Accuracy: 0.252
# Epochs: 9 | Train Loss: 0.021 | Train Accuracy: 0.191
# Val loss: 0.025 | Val Accuracy: 0.259
# Epochs: 10 | Train Loss: 0.021 | Train Accuracy: 0.178
# Val loss: 0.025 | Val Accuracy: 0.275
# Epochs: 11 | Train Loss: 0.020 | Train Accuracy: 0.191
# Val loss: 0.025 | Val Accuracy: 0.288
# Epochs: 12 | Train Loss: 0.020 | Train Accuracy: 0.195
# Val loss: 0.024 | Val Accuracy: 0.294
# Epochs: 13 | Train Loss: 0.020 | Train Accuracy: 0.218
# Val loss: 0.024 | Val Accuracy: 0.294
# Epochs: 14 | Train Loss: 0.020 | Train Accuracy: 0.206
# Val loss: 0.024 | Val Accuracy: 0.307
# Epochs: 15 | Train Loss: 0.020 | Train Accuracy: 0.232
# Val loss: 0.024 | Val Accuracy: 0.314
# Epochs: 16 | Train Loss: 0.020 | Train Accuracy: 0.233
# Val loss: 0.024 | Val Accuracy: 0.333
# Epochs: 17 | Train Loss: 0.020 | Train Accuracy: 0.214
# Val loss: 0.024 | Val Accuracy: 0.337
# Epochs: 18 | Train Loss: 0.020 | Train Accuracy: 0.239
# Val loss: 0.024 | Val Accuracy: 0.340
# Epochs: 19 | Train Loss: 0.020 | Train Accuracy: 0.247
# Val loss: 0.023 | Val Accuracy: 0.340
# Epochs: 20 | Train Loss: 0.019 | Train Accuracy: 0.247
# Val loss: 0.023 | Val Accuracy: 0.343
# Epochs: 21 | Train Loss: 0.019 | Train Accuracy: 0.245
# Val loss: 0.023 | Val Accuracy: 0.356
# Epochs: 22 | Train Loss: 0.019 | Train Accuracy: 0.235
# Val loss: 0.023 | Val Accuracy: 0.379
# Epochs: 23 | Train Loss: 0.019 | Train Accuracy: 0.267
# Val loss: 0.023 | Val Accuracy: 0.375
# Epochs: 24 | Train Loss: 0.019 | Train Accuracy: 0.266
# Val loss: 0.023 | Val Accuracy: 0.388
# Epochs: 25 | Train Loss: 0.019 | Train Accuracy: 0.277
# Val loss: 0.023 | Val Accuracy: 0.392
# Epochs: 26 | Train Loss: 0.019 | Train Accuracy: 0.287
# Val loss: 0.023 | Val Accuracy: 0.385
# Epochs: 27 | Train Loss: 0.019 | Train Accuracy: 0.288
# Val loss: 0.023 | Val Accuracy: 0.392
# Epochs: 55 | Train Loss: 0.017 | Train Accuracy: 0.393
# Val loss: 0.021 | Val Accuracy: 0.440
# Epochs: 56 | Train Loss: 0.017 | Train Accuracy: 0.397
# Val loss: 0.021 | Val Accuracy: 0.434
# Epochs: 57 | Train Loss: 0.017 | Train Accuracy: 0.406
# Val loss: 0.021 | Val Accuracy: 0.443
# Epochs: 58 | Train Loss: 0.017 | Train Accuracy: 0.404
# Val loss: 0.021 | Val Accuracy: 0.443
# Epochs: 59 | Train Loss: 0.016 | Train Accuracy: 0.415
# Val loss: 0.021 | Val Accuracy: 0.447
# Epochs: 60 | Train Loss: 0.016 | Train Accuracy: 0.415
# Val loss: 0.021 | Val Accuracy: 0.443
# Epochs: 61 | Train Loss: 0.016 | Train Accuracy: 0.425
# Val loss: 0.021 | Val Accuracy: 0.443
# Epochs: 62 | Train Loss: 0.016 | Train Accuracy: 0.421
# Val loss: 0.021 | Val Accuracy: 0.447
# Epochs: 63 | Train Loss: 0.016 | Train Accuracy: 0.431
# Val loss: 0.020 | Val Accuracy: 0.450
# Epochs: 64 | Train Loss: 0.016 | Train Accuracy: 0.431
# Val loss: 0.020 | Val Accuracy: 0.460
# Epochs: 65 | Train Loss: 0.016 | Train Accuracy: 0.422
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 66 | Train Loss: 0.016 | Train Accuracy: 0.432
# Val loss: 0.020 | Val Accuracy: 0.460
# Epochs: 67 | Train Loss: 0.016 | Train Accuracy: 0.426
# Val loss: 0.020 | Val Accuracy: 0.456
# Epochs: 68 | Train Loss: 0.016 | Train Accuracy: 0.433
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 69 | Train Loss: 0.016 | Train Accuracy: 0.431
# Val loss: 0.020 | Val Accuracy: 0.460
# Epochs: 70 | Train Loss: 0.016 | Train Accuracy: 0.440
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 71 | Train Loss: 0.016 | Train Accuracy: 0.436
# Val loss: 0.020 | Val Accuracy: 0.472
# Epochs: 72 | Train Loss: 0.016 | Train Accuracy: 0.428
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 73 | Train Loss: 0.016 | Train Accuracy: 0.439
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 74 | Train Loss: 0.016 | Train Accuracy: 0.431
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 75 | Train Loss: 0.016 | Train Accuracy: 0.452
# Val loss: 0.020 | Val Accuracy: 0.472
# Epochs: 76 | Train Loss: 0.016 | Train Accuracy: 0.451
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 77 | Train Loss: 0.015 | Train Accuracy: 0.462
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 78 | Train Loss: 0.016 | Train Accuracy: 0.445
# Val loss: 0.020 | Val Accuracy: 0.482
# Epochs: 79 | Train Loss: 0.015 | Train Accuracy: 0.474
# Val loss: 0.020 | Val Accuracy: 0.476
# Epochs: 80 | Train Loss: 0.015 | Train Accuracy: 0.450
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 81 | Train Loss: 0.015 | Train Accuracy: 0.471
# Val loss: 0.020 | Val Accuracy: 0.460
# Epochs: 82 | Train Loss: 0.015 | Train Accuracy: 0.458
# Val loss: 0.020 | Val Accuracy: 0.460
# Epochs: 83 | Train Loss: 0.015 | Train Accuracy: 0.463
# Val loss: 0.020 | Val Accuracy: 0.469
# Epochs: 84 | Train Loss: 0.015 | Train Accuracy: 0.473
# Val loss: 0.020 | Val Accuracy: 0.466
# Epochs: 85 | Train Loss: 0.015 | Train Accuracy: 0.481
# Epochs: 137 | Train Loss: 0.013 | Train Accuracy: 0.570
# Val loss: 0.018 | Val Accuracy: 0.502
# Epochs: 138 | Train Loss: 0.013 | Train Accuracy: 0.576
# Val loss: 0.018 | Val Accuracy: 0.495
# Epochs: 139 | Train Loss: 0.013 | Train Accuracy: 0.572
# Val loss: 0.018 | Val Accuracy: 0.508
# Epochs: 140 | Train Loss: 0.013 | Train Accuracy: 0.566
# Val loss: 0.018 | Val Accuracy: 0.505
# Epochs: 141 | Train Loss: 0.012 | Train Accuracy: 0.596
# Val loss: 0.018 | Val Accuracy: 0.511
# Epochs: 142 | Train Loss: 0.012 | Train Accuracy: 0.603
# Val loss: 0.018 | Val Accuracy: 0.508
# Epochs: 143 | Train Loss: 0.013 | Train Accuracy: 0.575
# Val loss: 0.018 | Val Accuracy: 0.505
# Epochs: 144 | Train Loss: 0.012 | Train Accuracy: 0.588
# Val loss: 0.018 | Val Accuracy: 0.505
# Epochs: 145 | Train Loss: 0.012 | Train Accuracy: 0.584
# Val loss: 0.018 | Val Accuracy: 0.505
# Epochs: 146 | Train Loss: 0.012 | Train Accuracy: 0.588
# Val loss: 0.018 | Val Accuracy: 0.508
# Epochs: 147 | Train Loss: 0.012 | Train Accuracy: 0.589
# Val loss: 0.018 | Val Accuracy: 0.508
# Epochs: 148 | Train Loss: 0.012 | Train Accuracy: 0.580
# Val loss: 0.018 | Val Accuracy: 0.505
# Epochs: 149 | Train Loss: 0.012 | Train Accuracy: 0.582
# Val loss: 0.018 | Val Accuracy: 0.508
# Epochs: 150 | Train Loss: 0.012 | Train Accuracy: 0.599
# Val loss: 0.018 | Val Accuracy: 0.502
# Classification Report:
#                            precision    recall  f1-score   support
#
#               flag_waving       0.59      0.49      0.54        45
# exaggeration,minimisation       0.48      0.50      0.49        30
# causal_oversimplification       0.43      0.57      0.49        35
#     name_calling,labeling       0.51      0.56      0.54        34
#                repetition       0.71      0.30      0.42        40
#                     doubt       0.44      0.58      0.50        43
#           loaded_language       0.56      0.56      0.56        39
#  appeal_to_fear_prejudice       0.51      0.53      0.52        43
#
#                  accuracy                           0.51       309
#                 macro avg       0.53      0.51      0.51       309
#              weighted avg       0.53      0.51      0.51       309
#
# Epochs: 1 | Train Loss: 0.022 | Train Accuracy: 0.118
# Val loss: 0.027 | Val Accuracy: 0.123
# Epochs: 2 | Train Loss: 0.022 | Train Accuracy: 0.139
# Val loss: 0.027 | Val Accuracy: 0.107
# Epochs: 3 | Train Loss: 0.022 | Train Accuracy: 0.139
# Val loss: 0.027 | Val Accuracy: 0.094
# Epochs: 4 | Train Loss: 0.022 | Train Accuracy: 0.144
# Val loss: 0.027 | Val Accuracy: 0.117
# Epochs: 5 | Train Loss: 0.022 | Train Accuracy: 0.153
# Val loss: 0.027 | Val Accuracy: 0.126
# Epochs: 6 | Train Loss: 0.022 | Train Accuracy: 0.149
# Val loss: 0.027 | Val Accuracy: 0.129
# Epochs: 7 | Train Loss: 0.021 | Train Accuracy: 0.167
# Val loss: 0.027 | Val Accuracy: 0.146
# Epochs: 8 | Train Loss: 0.021 | Train Accuracy: 0.188
# Val loss: 0.026 | Val Accuracy: 0.175
# Epochs: 9 | Train Loss: 0.021 | Train Accuracy: 0.154
# Val loss: 0.026 | Val Accuracy: 0.184
# Epochs: 10 | Train Loss: 0.021 | Train Accuracy: 0.167
# Val loss: 0.026 | Val Accuracy: 0.207
# Epochs: 11 | Train Loss: 0.021 | Train Accuracy: 0.165
# Val loss: 0.026 | Val Accuracy: 0.217
# Epochs: 12 | Train Loss: 0.021 | Train Accuracy: 0.197
# Val loss: 0.026 | Val Accuracy: 0.220
# Epochs: 13 | Train Loss: 0.020 | Train Accuracy: 0.192
# Val loss: 0.026 | Val Accuracy: 0.243
# Epochs: 14 | Train Loss: 0.020 | Train Accuracy: 0.211
# Val loss: 0.026 | Val Accuracy: 0.256
# Epochs: 15 | Train Loss: 0.020 | Train Accuracy: 0.204
# Val loss: 0.026 | Val Accuracy: 0.259
# Epochs: 16 | Train Loss: 0.020 | Train Accuracy: 0.204
# Val loss: 0.026 | Val Accuracy: 0.275
# Epochs: 17 | Train Loss: 0.020 | Train Accuracy: 0.210
# Val loss: 0.026 | Val Accuracy: 0.285
# Epochs: 18 | Train Loss: 0.020 | Train Accuracy: 0.229
# Val loss: 0.025 | Val Accuracy: 0.298
# Epochs: 19 | Train Loss: 0.020 | Train Accuracy: 0.224
# Val loss: 0.025 | Val Accuracy: 0.314
# Epochs: 20 | Train Loss: 0.020 | Train Accuracy: 0.204
# Val loss: 0.025 | Val Accuracy: 0.314
# Epochs: 21 | Train Loss: 0.020 | Train Accuracy: 0.225
# Val loss: 0.025 | Val Accuracy: 0.324
# Epochs: 22 | Train Loss: 0.020 | Train Accuracy: 0.242
# Val loss: 0.025 | Val Accuracy: 0.327
# Epochs: 23 | Train Loss: 0.020 | Train Accuracy: 0.236
# Val loss: 0.025 | Val Accuracy: 0.340
# Epochs: 24 | Train Loss: 0.020 | Train Accuracy: 0.228
# Val loss: 0.025 | Val Accuracy: 0.327
# Epochs: 25 | Train Loss: 0.019 | Train Accuracy: 0.242
# Val loss: 0.025 | Val Accuracy: 0.350
# Epochs: 26 | Train Loss: 0.019 | Train Accuracy: 0.246
# Val loss: 0.025 | Val Accuracy: 0.340
# Epochs: 27 | Train Loss: 0.020 | Train Accuracy: 0.251
# Val loss: 0.025 | Val Accuracy: 0.330
# Epochs: 28 | Train Loss: 0.019 | Train Accuracy: 0.262
# Val loss: 0.025 | Val Accuracy: 0.333
# Epochs: 29 | Train Loss: 0.019 | Train Accuracy: 0.280
# Val loss: 0.025 | Val Accuracy: 0.343
# Epochs: 30 | Train Loss: 0.019 | Train Accuracy: 0.263
# Val loss: 0.025 | Val Accuracy: 0.340
# Epochs: 31 | Train Loss: 0.019 | Train Accuracy: 0.297
# Val loss: 0.024 | Val Accuracy: 0.350
# Epochs: 32 | Train Loss: 0.019 | Train Accuracy: 0.266
# Val loss: 0.024 | Val Accuracy: 0.343
# Epochs: 33 | Train Loss: 0.019 | Train Accuracy: 0.300
# Val loss: 0.024 | Val Accuracy: 0.350
# Val loss: 0.021 | Val Accuracy: 0.405
# Epochs: 126 | Train Loss: 0.014 | Train Accuracy: 0.507
# Val loss: 0.021 | Val Accuracy: 0.401
# Epochs: 127 | Train Loss: 0.014 | Train Accuracy: 0.514
# Val loss: 0.021 | Val Accuracy: 0.405
# Epochs: 128 | Train Loss: 0.014 | Train Accuracy: 0.527
# Val loss: 0.021 | Val Accuracy: 0.411
# Epochs: 129 | Train Loss: 0.014 | Train Accuracy: 0.541
# Val loss: 0.021 | Val Accuracy: 0.411
# Epochs: 130 | Train Loss: 0.014 | Train Accuracy: 0.517
# Val loss: 0.021 | Val Accuracy: 0.405
# Epochs: 131 | Train Loss: 0.014 | Train Accuracy: 0.531
# Val loss: 0.021 | Val Accuracy: 0.405
# Epochs: 132 | Train Loss: 0.014 | Train Accuracy: 0.541
# Val loss: 0.021 | Val Accuracy: 0.411
# Epochs: 133 | Train Loss: 0.014 | Train Accuracy: 0.515
# Val loss: 0.021 | Val Accuracy: 0.411
# Epochs: 134 | Train Loss: 0.014 | Train Accuracy: 0.503
# Val loss: 0.021 | Val Accuracy: 0.411
# Epochs: 135 | Train Loss: 0.014 | Train Accuracy: 0.524
# Val loss: 0.021 | Val Accuracy: 0.405
# Epochs: 136 | Train Loss: 0.014 | Train Accuracy: 0.527
# Val loss: 0.021 | Val Accuracy: 0.408
# Epochs: 137 | Train Loss: 0.013 | Train Accuracy: 0.539
# Val loss: 0.021 | Val Accuracy: 0.408
# Epochs: 138 | Train Loss: 0.013 | Train Accuracy: 0.538
# Val loss: 0.021 | Val Accuracy: 0.408
# Epochs: 139 | Train Loss: 0.013 | Train Accuracy: 0.530
# Val loss: 0.021 | Val Accuracy: 0.408
# Epochs: 140 | Train Loss: 0.013 | Train Accuracy: 0.529
# Val loss: 0.021 | Val Accuracy: 0.408
# Epochs: 141 | Train Loss: 0.013 | Train Accuracy: 0.522
# Val loss: 0.021 | Val Accuracy: 0.414
# Epochs: 142 | Train Loss: 0.013 | Train Accuracy: 0.547
# Val loss: 0.021 | Val Accuracy: 0.414
# Epochs: 143 | Train Loss: 0.013 | Train Accuracy: 0.552
# Val loss: 0.021 | Val Accuracy: 0.414
# Epochs: 144 | Train Loss: 0.013 | Train Accuracy: 0.548
# Val loss: 0.021 | Val Accuracy: 0.411
# Epochs: 145 | Train Loss: 0.013 | Train Accuracy: 0.548
# Val loss: 0.021 | Val Accuracy: 0.414
# Epochs: 146 | Train Loss: 0.013 | Train Accuracy: 0.551
# Val loss: 0.021 | Val Accuracy: 0.414
# Epochs: 147 | Train Loss: 0.013 | Train Accuracy: 0.551
# Val loss: 0.021 | Val Accuracy: 0.411
# Epochs: 148 | Train Loss: 0.013 | Train Accuracy: 0.553
# Val loss: 0.021 | Val Accuracy: 0.417
# Epochs: 149 | Train Loss: 0.013 | Train Accuracy: 0.537
# Val loss: 0.021 | Val Accuracy: 0.414
# Epochs: 150 | Train Loss: 0.013 | Train Accuracy: 0.559
# Val loss: 0.021 | Val Accuracy: 0.417
# Classification Report:
#                            precision    recall  f1-score   support
#
#               flag_waving       0.47      0.18      0.26        45
# exaggeration,minimisation       0.44      0.47      0.45        30
# causal_oversimplification       0.34      0.49      0.40        35
#     name_calling,labeling       0.52      0.44      0.48        34
#                repetition       0.30      0.42      0.35        40
#                     doubt       0.45      0.44      0.45        43
#           loaded_language       0.50      0.44      0.47        39
#  appeal_to_fear_prejudice       0.45      0.51      0.48        43
#
#                  accuracy                           0.42       309
#                 macro avg       0.43      0.42      0.42       309
#              weighted avg       0.43      0.42      0.41       309
